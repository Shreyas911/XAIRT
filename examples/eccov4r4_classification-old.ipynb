# %%
### Import the required libraries
import numpy as np
import scipy
import matplotlib.pyplot as plt 

import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter("ignore")

import tensorflow as tf
import tensorflow.keras as keras
import innvestigate
tf.compat.v1.disable_eager_execution()

import os
from os.path import join
import sys

import xarray as xr
import xmitgcm
from xmitgcm import open_mdsdataset
import ecco_v4_py as ecco

# Append to sys.path the absolute path to src/XAIRT
path_list = os.path.abspath('').split('/')
path_src_XAIRT = ''
for link in path_list[:-1]:
    path_src_XAIRT = path_src_XAIRT+link+'/'
sys.path.append(path_src_XAIRT+'/src')

# Now import module XAIRT
from XAIRT import *

# See if GPUs are available
from keras import backend as K
if bool(K._get_available_gpus()):
    print("Running on GPU")
else:
    print("Running on CPU")
# Out:
# 2023-10-19 13:44:11.793440: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Running on GPU
# 2023-10-19 13:44:25.186112: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38251 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2023-10-19 13:44:25.238708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38251 MB memory:  -> device: 1, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# 2023-10-19 13:44:25.240970: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 38251 MB memory:  -> device: 2, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:e2:00.0, compute capability: 8.0

# %%
### Sverdrup 
# mainDir  = '/scratch2/pillarh/eccov4r4'
# gridDir  = mainDir + '/GRID'
# thetaDir = mainDir + '/eccov4r4_nctiles_daily/THETA'

### Lonestar6
mainDir  = '/work/07665/shrey911/ls6/LRP_eccov4r4_data'
gridDir  = mainDir
thetaDir = mainDir

# %%
# %%capture --no-stderr --no-stdout --no-display 

# #### https://stackoverflow.com/questions/72821108/hdf5-warnings-when-accessing-xarray-dataset
# #### Necessary to suppress stderr output that crashes the file
# from dask.distributed import Client
# c = Client(threads_per_worker=1)

# #### Write thetaSurf data year-wise to netcdf file in scracth2
# #### I did it manually one year at a time in list `years` since stderr output crashes the file

# def subset(ds):
#     dict_subset = {'k':0}
#     ds_subset = ds.isel(dict_subset); # ; at the end to suppress output
#     return ds_subset; # ; at the end to suppress output

# years = np.arange(1992,2018)

# # for year in years:
# #     ds = xr.open_mfdataset(join(thetaDir,f'{year}/*/*.nc'), preprocess=subset); # ; at the end to suppress output
# #     ds.to_netcdf(f'/scratch2/shreyas/LRP_eccov4r4_data/thetaSurfECCOv4r4_{year}.nc', mode='w')

# for year in years:
#     print(year)
#     ds = xr.open_mfdataset(join(saltDir,f'{year}/*/*.nc'), preprocess=subset); # ; at the end to suppress output
#     ds.to_netcdf(f'/scratch2/shreyas/LRP_eccov4r4_data/saltSurfECCOv4r4_{year}.nc', mode='w')

# %%
### Sverdrup  - /scratch2/shreyas/LRP_eccov4r4_data
### Lonestar6 - /work/07665/shrey911/ls6/LRP_eccov4r4_data

ds = xr.open_dataset(f'/work/07665/shrey911/ls6/LRP_eccov4r4_data/thetaSurfECCOv4r4.nc')

# %%
hFacC = ecco.read_llc_to_tiles(gridDir, 'hFacC.data')
hFacC_mask = hFacC > 0
hFacC_mask = hFacC_mask.astype(float)

XC = ds['XC'].data
YC = ds['YC'].data

latMask = YC > -20.0
latMask = latMask.astype(float)

maskFinal = hFacC_mask * latMask
NaNmaskFinal = np.copy(maskFinal)
NaNmaskFinal[NaNmaskFinal == 0] = np.nan

da_hFacC_mask = xr.DataArray(
    data=hFacC_mask,
    dims=["tile", "j", "i"],
    coords=dict(
        tile = ds['tile'].data,
        j    = ds['j'].data,
        i    = ds['i'].data,
    ),
    attrs=dict(description="hFacC mask 2D 1 if > 0, else 0"),
)

da_latMask = xr.DataArray(
    data=latMask,
    dims=["tile", "j", "i"],
    coords=dict(
        tile = ds['tile'].data,
        j    = ds['j'].data,
        i    = ds['i'].data,
    ),
    attrs=dict(description="Latitude Mask 1 if > -20, else 0"),
)

da_maskFinal = xr.DataArray(
    data=maskFinal,
    dims=["tile", "j", "i"],
    coords=dict(
        tile = ds['tile'].data,
        j    = ds['j'].data,
        i    = ds['i'].data,
    ),
    attrs=dict(description="Mask 2D 1 if > 0, else 0"),
)

da_NaNmaskFinal = xr.DataArray(
    data=NaNmaskFinal,
    dims=["tile", "j", "i"],
    coords=dict(
        tile = ds['tile'].data,
        j    = ds['j'].data,
        i    = ds['i'].data,
    ),
    attrs=dict(description="Mask 2D True if > 0, else NaN"),
)

ds = ds.assign(hFacC_mask   = da_hFacC_mask,
          latMask      = da_latMask,
          maskFinal    = da_maskFinal,
          NaNmaskFinal = da_NaNmaskFinal)

wetpoints = np.nonzero(ds['maskFinal'].data)
# Out:
# load_binary_array: loading file /work/07665/shrey911/ls6/LRP_eccov4r4_data/hFacC.data
# load_binary_array: data array shape  (1170, 90)
# load_binary_array: data array type  >f4
# llc_compact_to_faces: dims, llc  (1170, 90) 90
# llc_compact_to_faces: data_compact array type  >f4
# llc_faces_to_tiles: data_tiles shape  (13, 90, 90)
# llc_faces_to_tiles: data_tiles dtype  >f4

# %%
X_2d = ds['THETA'].transpose("time","j","i","tile").data

### X_2d is transposed, so order of wetpoint array changes, note in next line
X    = ds['THETA'].data[:,wetpoints[0],wetpoints[1],wetpoints[2]]
y    = ds['THETA'].isel(tile = 10, j = 1, i = 43).data

# %%
plt.pcolor(ds['XC'].isel(tile = 10), ds['YC'].isel(tile = 10), 
           ds['NaNmaskFinal'].isel(tile = 10)*ds['THETA'].isel(time = 0, tile = 10), 
           cmap = 'jet', vmax = 35)
plt.colorbar()
plt.scatter(-126.0, 50.0, color = 'brown', label = '234E, 50 N')
plt.scatter(ds['XC'].isel(tile = 10, j = 1, i = 43),
            ds['YC'].isel(tile = 10, j = 1, i = 43),
            color = 'black', label = 'Objective function point')
plt.legend()

# %%
plt.figure(figsize=(15,5))

P = ecco.plot_proj_to_latlon_grid(ds['XC'], ds['YC'],
                              ds['THETA'].isel(time = 0),
                              plot_type = 'contourf',
                              show_colorbar=True, cmap='jet', cmax = 35,
                              dx=2, dy=2, projection_type = 'robin',
                              less_output = True, subplot_grid = [1,2,1]);
P[1].set_title("Theta 1992_01_01")

P = ecco.plot_proj_to_latlon_grid(ds['XC'], ds['YC'],
                              ds['NaNmaskFinal']*ds['THETA'].isel(time = 0),
                              plot_type = 'contourf',
                              show_colorbar=True, cmap='jet', cmax = 35,
                              dx=2, dy=2, projection_type = 'robin',
                              less_output = True, subplot_grid = [1,2,2]);
P[1].set_title("MaskedTheta 1992_01_01")
# Out:
# Text(0.5, 1.0, 'MaskedTheta 1992_01_01')

# %%
yOrig = np.copy(y)
y = y - np.mean(y)
scipy.signal.detrend(y, axis=0, type='linear', bp=0, overwrite_data=True)
# https://stackoverflow.com/questions/13728392/moving-average-or-running-mean
y = np.convolve(y, np.ones(60)/60, mode='valid')
oneHotCost = np.zeros((y.shape[0], 2), dtype = int)
oneHotCost[:,0] = y >= 0.0
oneHotCost[:,1] = y <  0.0

XOrig = np.copy(X)
X = X - np.mean(X, axis = 0)
scipy.signal.detrend(X, axis=0, type='linear', bp=0, overwrite_data=True)
# Out:
# array([[ 0.02956464,  0.39354905,  0.60739046, ..., -0.22821362,
#         -0.56106365, -0.580769  ],
#        [ 0.08552834,  0.43018246,  0.6337905 , ..., -0.22814432,
#         -0.50713784, -0.53854316],
#        [ 0.17864148,  0.51143825,  0.70720285, ..., -0.23423767,
#         -0.42273647, -0.4466232 ],
#        ...,
#        [ 0.64544654,  0.6204724 ,  0.6109738 , ...,  0.24748713,
#          0.34844324,  0.64917463],
#        [ 0.7172966 ,  0.7014955 ,  0.70182306, ...,  0.28836986,
#          0.3896737 ,  0.7097091 ],
#        [ 0.6977293 ,  0.6945498 ,  0.7080319 , ...,  0.22857894,
#          0.3344629 ,  0.6765871 ]], dtype=float32)

# %%
def quickSetup(X, y, X_full, numVars, lrp_methods, **NNkwargs):
    
    result = {}
    
    K = TrainFullyConnectedNN(X, y, **NNkwargs)
        
    best_model = K.quickTrain()
    result['cost_predict_NN'] = best_model.predict(X_full)
    normalizeDict = {'bool_': True, 'kind': 'MaxAbs'}
    kwargs = {'y_ref': 0.00}
    
    # Create model without trailing softmax
    model_wo_softmax = innvestigate.model_wo_softmax(best_model)
    for method in lrp_methods:
    
        title = method['title']
        print(f'Analyze using {title}')
        
        Xplain = XAIR(model_wo_softmax, method, 'classic', X_full, normalizeDict, **kwargs)
        a, _  = Xplain.quick_analyze()
        perVar = int(a.shape[1]/numVars)
        
        rel = np.zeros((numVars, a.shape[0], 13, 90, 90))
        rel[:,:,:,:,:] = np.nan
            
        for numvar in range(numVars):
            rel[numvar,:,wetpoints[0],wetpoints[1],wetpoints[2]] = a[:,numvar*perVar:(numvar+1)*perVar].T
        result[method['name']] = rel
      
    return result

# %%
Layers = [{'size': X.shape[1], 'activation': None    , 'use_bias': None},
          {'size': 3000      , 'activation': 'relu'  , 'use_bias': True},
          {'size': 1000       , 'activation': 'relu'  , 'use_bias': True},
          {'size': 2         , 'activation': 'softmax', 'use_bias': False}]
Losses = [{'kind': 'categorical_crossentropy', 'weight': 1.0}]

LRPDict_theta = {}
lagStepsList = [-60,0,60,120,180]

NNkwargs = {'losses': Losses, 'optim': 'adam', 'metrics': ['accuracy'],
            'batch_size': 10, 'epochs': 100, 'validation_split': 0.1,
            'filename': 'model', 'dirname': os.path.abspath('')}

methods = \
[dict(name='gradient',                     optParams = {"postprocess": "abs"}, title = 'Gradient'),
 # dict(name='guided_backprop',              optParams = {}                    , title = 'Guided Backprop'),
 dict(name='lrp.z',                        optParams = {}                    , title = 'LRP-Z'),
 dict(name='lrp.epsilon',                  optParams = {"epsilon": 1}        , title = 'LRP-Epsilon'),
 dict(name='lrp.alpha_1_beta_0',           optParams = {}                    , title = 'LRP-Alpha-1-Beta-0')
 # dict(name='lrp.sequential_preset_a_flat', optParams = {"epsilon": 1}        , title = 'LRP-PresetAFlat'),
 # dict(name='lrp.sequential_preset_b_flat', optParams = {"epsilon": 1}        , title = 'LRP-PresetBFlat'),
]

# %%
for i in range(len(lagStepsList)):

    print(f'Lag: {lagStepsList[i]} days, for Theta')
    
    ### This is just a hack to automate stuff, it has no deep meaning
    ### It ensures X and y have the same size after the appropriate time lag
    Xi = (lagStepsList[i]>0)*0+(lagStepsList[i]<=0)*(30-lagStepsList[i])
    Xf = -29-lagStepsList[i] if lagStepsList[i]>=0 else None
    yi = lagStepsList[i]-30 if lagStepsList[i]>0 else 0
    yf = lagStepsList[i]+29 if lagStepsList[i]<0 else None
    
    LRPDict_theta[f'LRP{lagStepsList[i]}'] = quickSetup(X[Xi:Xf], oneHotCost[yi:yf], X, numVars = 1, 
                                                        lrp_methods = methods,
                                                        layers = Layers, **NNkwargs)
# Out:
# Lag: -60 days, for Theta
# 2023-10-19 13:45:10.890198: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38251 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2023-10-19 13:45:10.892021: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38251 MB memory:  -> device: 1, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# 2023-10-19 13:45:10.893862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 38251 MB memory:  -> device: 2, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:e2:00.0, compute capability: 8.0
# 2023-10-19 13:45:10.945448: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2023-10-19 13:45:34.208485: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Epoch 1: val_loss improved from inf to 0.48268, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 2: val_loss improved from 0.48268 to 0.28610, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 3: val_loss did not improve from 0.28610
#
# Epoch 4: val_loss improved from 0.28610 to 0.13366, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 5: val_loss did not improve from 0.13366
#
# Epoch 6: val_loss did not improve from 0.13366
#
# Epoch 7: val_loss did not improve from 0.13366
#
# Epoch 8: val_loss did not improve from 0.13366
#
# Epoch 9: val_loss did not improve from 0.13366
#
# Epoch 10: val_loss did not improve from 0.13366
#
# Epoch 11: val_loss did not improve from 0.13366
#
# Epoch 12: val_loss did not improve from 0.13366
#
# Epoch 13: val_loss did not improve from 0.13366
#
# Epoch 14: val_loss did not improve from 0.13366
#
# Epoch 15: val_loss did not improve from 0.13366
#
# Epoch 16: val_loss did not improve from 0.13366
#
# Epoch 17: val_loss did not improve from 0.13366
#
# Epoch 18: val_loss did not improve from 0.13366
#
# Epoch 19: val_loss did not improve from 0.13366
#
# Epoch 20: val_loss did not improve from 0.13366
#
# Epoch 21: val_loss did not improve from 0.13366
#
# Epoch 22: val_loss did not improve from 0.13366
#
# Epoch 23: val_loss did not improve from 0.13366
#
# Epoch 24: val_loss did not improve from 0.13366
#
# Epoch 25: val_loss did not improve from 0.13366
#
# Epoch 26: val_loss did not improve from 0.13366
#
# Epoch 27: val_loss did not improve from 0.13366
#
# Epoch 28: val_loss did not improve from 0.13366
#
# Epoch 29: val_loss did not improve from 0.13366
#
# Epoch 30: val_loss did not improve from 0.13366
#
# Epoch 31: val_loss did not improve from 0.13366
#
# Epoch 32: val_loss did not improve from 0.13366
#
# Epoch 33: val_loss did not improve from 0.13366
#
# Epoch 34: val_loss did not improve from 0.13366
#
# Epoch 35: val_loss did not improve from 0.13366
#
# Epoch 36: val_loss did not improve from 0.13366
#
# Epoch 37: val_loss did not improve from 0.13366
#
# Epoch 38: val_loss did not improve from 0.13366
#
# Epoch 39: val_loss did not improve from 0.13366
#
# Epoch 40: val_loss did not improve from 0.13366
#
# Epoch 41: val_loss did not improve from 0.13366
#
# Epoch 42: val_loss did not improve from 0.13366
#
# Epoch 43: val_loss did not improve from 0.13366
#
# Epoch 44: val_loss did not improve from 0.13366
#
# Epoch 45: val_loss did not improve from 0.13366
#
# Epoch 46: val_loss did not improve from 0.13366
#
# Epoch 47: val_loss did not improve from 0.13366
#
# Epoch 48: val_loss did not improve from 0.13366
#
# Epoch 49: val_loss did not improve from 0.13366
#
# Epoch 50: val_loss did not improve from 0.13366
#
# Epoch 51: val_loss did not improve from 0.13366
#
# Epoch 52: val_loss did not improve from 0.13366
#
# Epoch 53: val_loss did not improve from 0.13366
#
# Epoch 54: val_loss did not improve from 0.13366
#
# Epoch 55: val_loss did not improve from 0.13366
#
# Epoch 56: val_loss did not improve from 0.13366
#
# Epoch 57: val_loss did not improve from 0.13366
#
# Epoch 58: val_loss did not improve from 0.13366
#
# Epoch 59: val_loss did not improve from 0.13366
#
# Epoch 60: val_loss did not improve from 0.13366
#
# Epoch 61: val_loss did not improve from 0.13366
#
# Epoch 62: val_loss did not improve from 0.13366
#
# Epoch 63: val_loss did not improve from 0.13366
#
# Epoch 64: val_loss did not improve from 0.13366
#
# Epoch 65: val_loss did not improve from 0.13366
#
# Epoch 66: val_loss did not improve from 0.13366
#
# Epoch 67: val_loss did not improve from 0.13366
#
# Epoch 68: val_loss did not improve from 0.13366
#
# Epoch 69: val_loss did not improve from 0.13366
#
# Epoch 70: val_loss did not improve from 0.13366
#
# Epoch 71: val_loss did not improve from 0.13366
#
# Epoch 72: val_loss did not improve from 0.13366
#
# Epoch 73: val_loss did not improve from 0.13366
#
# Epoch 74: val_loss did not improve from 0.13366
#
# Epoch 75: val_loss did not improve from 0.13366
#
# Epoch 76: val_loss did not improve from 0.13366
#
# Epoch 77: val_loss did not improve from 0.13366
#
# Epoch 78: val_loss did not improve from 0.13366
#
# Epoch 79: val_loss did not improve from 0.13366
#
# Epoch 80: val_loss did not improve from 0.13366
#
# Epoch 81: val_loss did not improve from 0.13366
#
# Epoch 82: val_loss did not improve from 0.13366
#
# Epoch 83: val_loss did not improve from 0.13366
#
# Epoch 84: val_loss did not improve from 0.13366
#
# Epoch 85: val_loss did not improve from 0.13366
#
# Epoch 86: val_loss did not improve from 0.13366
#
# Epoch 87: val_loss did not improve from 0.13366
#
# Epoch 88: val_loss did not improve from 0.13366
#
# Epoch 89: val_loss did not improve from 0.13366
#
# Epoch 90: val_loss did not improve from 0.13366
#
# Epoch 91: val_loss did not improve from 0.13366
#
# Epoch 92: val_loss did not improve from 0.13366
#
# Epoch 93: val_loss did not improve from 0.13366
#
# Epoch 94: val_loss did not improve from 0.13366
#
# Epoch 95: val_loss did not improve from 0.13366
#
# Epoch 96: val_loss did not improve from 0.13366
#
# Epoch 97: val_loss did not improve from 0.13366
#
# Epoch 98: val_loss did not improve from 0.13366
#
# Epoch 99: val_loss did not improve from 0.13366
#
# Epoch 100: val_loss did not improve from 0.13366
# Analyze using Gradient
# Analyze using LRP-Z
# Analyze using LRP-Epsilon
# Analyze using LRP-Alpha-1-Beta-0
# Lag: 0 days, for Theta
# 2023-10-19 13:58:12.317918: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38251 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2023-10-19 13:58:12.319737: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38251 MB memory:  -> device: 1, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# 2023-10-19 13:58:12.321573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 38251 MB memory:  -> device: 2, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:e2:00.0, compute capability: 8.0
# Epoch 1: val_loss improved from inf to 0.22789, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 2: val_loss improved from 0.22789 to 0.12162, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 3: val_loss did not improve from 0.12162
#
# Epoch 4: val_loss did not improve from 0.12162
#
# Epoch 5: val_loss did not improve from 0.12162
#
# Epoch 6: val_loss did not improve from 0.12162
#
# Epoch 7: val_loss did not improve from 0.12162
#
# Epoch 8: val_loss did not improve from 0.12162
#
# Epoch 9: val_loss did not improve from 0.12162
#
# Epoch 10: val_loss did not improve from 0.12162
#
# Epoch 11: val_loss did not improve from 0.12162
#
# Epoch 12: val_loss did not improve from 0.12162
#
# Epoch 13: val_loss did not improve from 0.12162
#
# Epoch 14: val_loss did not improve from 0.12162
#
# Epoch 15: val_loss did not improve from 0.12162
#
# Epoch 16: val_loss did not improve from 0.12162
#
# Epoch 17: val_loss did not improve from 0.12162
#
# Epoch 18: val_loss did not improve from 0.12162
#
# Epoch 19: val_loss did not improve from 0.12162
#
# Epoch 20: val_loss did not improve from 0.12162
#
# Epoch 21: val_loss did not improve from 0.12162
#
# Epoch 22: val_loss did not improve from 0.12162
#
# Epoch 23: val_loss did not improve from 0.12162
#
# Epoch 24: val_loss did not improve from 0.12162
#
# Epoch 25: val_loss did not improve from 0.12162
#
# Epoch 26: val_loss did not improve from 0.12162
#
# Epoch 27: val_loss did not improve from 0.12162
#
# Epoch 28: val_loss did not improve from 0.12162
#
# Epoch 29: val_loss did not improve from 0.12162
#
# Epoch 30: val_loss did not improve from 0.12162
#
# Epoch 31: val_loss did not improve from 0.12162
#
# Epoch 32: val_loss did not improve from 0.12162
#
# Epoch 33: val_loss did not improve from 0.12162
#
# Epoch 34: val_loss did not improve from 0.12162
#
# Epoch 35: val_loss did not improve from 0.12162
#
# Epoch 36: val_loss did not improve from 0.12162
#
# Epoch 37: val_loss did not improve from 0.12162
#
# Epoch 38: val_loss did not improve from 0.12162
#
# Epoch 39: val_loss did not improve from 0.12162
#
# Epoch 40: val_loss did not improve from 0.12162
#
# Epoch 41: val_loss did not improve from 0.12162
#
# Epoch 42: val_loss did not improve from 0.12162
#
# Epoch 43: val_loss did not improve from 0.12162
#
# Epoch 44: val_loss did not improve from 0.12162
#
# Epoch 45: val_loss did not improve from 0.12162
#
# Epoch 46: val_loss did not improve from 0.12162
#
# Epoch 47: val_loss did not improve from 0.12162
#
# Epoch 48: val_loss did not improve from 0.12162
#
# Epoch 49: val_loss did not improve from 0.12162
#
# Epoch 50: val_loss did not improve from 0.12162
#
# Epoch 51: val_loss did not improve from 0.12162
#
# Epoch 52: val_loss did not improve from 0.12162
#
# Epoch 53: val_loss did not improve from 0.12162
#
# Epoch 54: val_loss did not improve from 0.12162
#
# Epoch 55: val_loss did not improve from 0.12162
#
# Epoch 56: val_loss did not improve from 0.12162
#
# Epoch 57: val_loss did not improve from 0.12162
#
# Epoch 58: val_loss did not improve from 0.12162
#
# Epoch 59: val_loss did not improve from 0.12162
#
# Epoch 60: val_loss did not improve from 0.12162
#
# Epoch 61: val_loss did not improve from 0.12162
#
# Epoch 62: val_loss did not improve from 0.12162
#
# Epoch 63: val_loss did not improve from 0.12162
#
# Epoch 64: val_loss did not improve from 0.12162
#
# Epoch 65: val_loss did not improve from 0.12162
#
# Epoch 66: val_loss did not improve from 0.12162
#
# Epoch 67: val_loss did not improve from 0.12162
#
# Epoch 68: val_loss did not improve from 0.12162
#
# Epoch 69: val_loss did not improve from 0.12162
#
# Epoch 70: val_loss did not improve from 0.12162
#
# Epoch 71: val_loss did not improve from 0.12162
#
# Epoch 72: val_loss did not improve from 0.12162
#
# Epoch 73: val_loss did not improve from 0.12162
#
# Epoch 74: val_loss did not improve from 0.12162
#
# Epoch 75: val_loss did not improve from 0.12162
#
# Epoch 76: val_loss did not improve from 0.12162
#
# Epoch 77: val_loss did not improve from 0.12162
#
# Epoch 78: val_loss did not improve from 0.12162
#
# Epoch 79: val_loss did not improve from 0.12162
#
# Epoch 80: val_loss did not improve from 0.12162
#
# Epoch 81: val_loss did not improve from 0.12162
#
# Epoch 82: val_loss did not improve from 0.12162
#
# Epoch 83: val_loss did not improve from 0.12162
#
# Epoch 84: val_loss did not improve from 0.12162
#
# Epoch 85: val_loss did not improve from 0.12162
#
# Epoch 86: val_loss did not improve from 0.12162
#
# Epoch 87: val_loss did not improve from 0.12162
#
# Epoch 88: val_loss did not improve from 0.12162
#
# Epoch 89: val_loss did not improve from 0.12162
#
# Epoch 90: val_loss did not improve from 0.12162
#
# Epoch 91: val_loss did not improve from 0.12162
#
# Epoch 92: val_loss did not improve from 0.12162
#
# Epoch 93: val_loss did not improve from 0.12162
#
# Epoch 94: val_loss did not improve from 0.12162
#
# Epoch 95: val_loss did not improve from 0.12162
#
# Epoch 96: val_loss did not improve from 0.12162
#
# Epoch 97: val_loss did not improve from 0.12162
#
# Epoch 98: val_loss did not improve from 0.12162
#
# Epoch 99: val_loss did not improve from 0.12162
#
# Epoch 100: val_loss did not improve from 0.12162
# Analyze using Gradient
# Analyze using LRP-Z
# Analyze using LRP-Epsilon
# Analyze using LRP-Alpha-1-Beta-0
# Lag: 60 days, for Theta
# 2023-10-19 14:10:31.158102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38251 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2023-10-19 14:10:31.159909: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38251 MB memory:  -> device: 1, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# 2023-10-19 14:10:31.161734: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 38251 MB memory:  -> device: 2, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:e2:00.0, compute capability: 8.0
# Epoch 1: val_loss improved from inf to 0.67845, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 2: val_loss improved from 0.67845 to 0.13897, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 3: val_loss did not improve from 0.13897
#
# Epoch 4: val_loss did not improve from 0.13897
#
# Epoch 5: val_loss did not improve from 0.13897
#
# Epoch 6: val_loss did not improve from 0.13897
#
# Epoch 7: val_loss did not improve from 0.13897
#
# Epoch 8: val_loss did not improve from 0.13897
#
# Epoch 9: val_loss did not improve from 0.13897
#
# Epoch 10: val_loss did not improve from 0.13897
#
# Epoch 11: val_loss did not improve from 0.13897
#
# Epoch 12: val_loss did not improve from 0.13897
#
# Epoch 13: val_loss did not improve from 0.13897
#
# Epoch 14: val_loss did not improve from 0.13897
#
# Epoch 15: val_loss did not improve from 0.13897
#
# Epoch 16: val_loss did not improve from 0.13897
#
# Epoch 17: val_loss did not improve from 0.13897
#
# Epoch 18: val_loss did not improve from 0.13897
#
# Epoch 19: val_loss did not improve from 0.13897
#
# Epoch 20: val_loss did not improve from 0.13897
#
# Epoch 21: val_loss did not improve from 0.13897
#
# Epoch 22: val_loss did not improve from 0.13897
#
# Epoch 23: val_loss did not improve from 0.13897
#
# Epoch 24: val_loss did not improve from 0.13897
#
# Epoch 25: val_loss did not improve from 0.13897
#
# Epoch 26: val_loss did not improve from 0.13897
#
# Epoch 27: val_loss did not improve from 0.13897
#
# Epoch 28: val_loss did not improve from 0.13897
#
# Epoch 29: val_loss did not improve from 0.13897
#
# Epoch 30: val_loss did not improve from 0.13897
#
# Epoch 31: val_loss did not improve from 0.13897
#
# Epoch 32: val_loss did not improve from 0.13897
#
# Epoch 33: val_loss did not improve from 0.13897
#
# Epoch 34: val_loss did not improve from 0.13897
#
# Epoch 35: val_loss did not improve from 0.13897
#
# Epoch 36: val_loss did not improve from 0.13897
#
# Epoch 37: val_loss did not improve from 0.13897
#
# Epoch 38: val_loss did not improve from 0.13897
#
# Epoch 39: val_loss did not improve from 0.13897
#
# Epoch 40: val_loss did not improve from 0.13897
#
# Epoch 41: val_loss did not improve from 0.13897
#
# Epoch 42: val_loss did not improve from 0.13897
#
# Epoch 43: val_loss did not improve from 0.13897
#
# Epoch 44: val_loss did not improve from 0.13897
#
# Epoch 45: val_loss did not improve from 0.13897
#
# Epoch 46: val_loss did not improve from 0.13897
#
# Epoch 47: val_loss did not improve from 0.13897
#
# Epoch 48: val_loss did not improve from 0.13897
#
# Epoch 49: val_loss did not improve from 0.13897
#
# Epoch 50: val_loss did not improve from 0.13897
#
# Epoch 51: val_loss did not improve from 0.13897
#
# Epoch 52: val_loss did not improve from 0.13897
#
# Epoch 53: val_loss did not improve from 0.13897
#
# Epoch 54: val_loss did not improve from 0.13897
#
# Epoch 55: val_loss did not improve from 0.13897
#
# Epoch 56: val_loss did not improve from 0.13897
#
# Epoch 57: val_loss did not improve from 0.13897
#
# Epoch 58: val_loss did not improve from 0.13897
#
# Epoch 59: val_loss did not improve from 0.13897
#
# Epoch 60: val_loss did not improve from 0.13897
#
# Epoch 61: val_loss did not improve from 0.13897
#
# Epoch 62: val_loss did not improve from 0.13897
#
# Epoch 63: val_loss did not improve from 0.13897
#
# Epoch 64: val_loss did not improve from 0.13897
#
# Epoch 65: val_loss did not improve from 0.13897
#
# Epoch 66: val_loss did not improve from 0.13897
#
# Epoch 67: val_loss did not improve from 0.13897
#
# Epoch 68: val_loss did not improve from 0.13897
#
# Epoch 69: val_loss did not improve from 0.13897
#
# Epoch 70: val_loss did not improve from 0.13897
#
# Epoch 71: val_loss did not improve from 0.13897
#
# Epoch 72: val_loss did not improve from 0.13897
#
# Epoch 73: val_loss did not improve from 0.13897
#
# Epoch 74: val_loss did not improve from 0.13897
#
# Epoch 75: val_loss did not improve from 0.13897
#
# Epoch 76: val_loss did not improve from 0.13897
#
# Epoch 77: val_loss did not improve from 0.13897
#
# Epoch 78: val_loss did not improve from 0.13897
#
# Epoch 79: val_loss did not improve from 0.13897
#
# Epoch 80: val_loss did not improve from 0.13897
#
# Epoch 81: val_loss did not improve from 0.13897
#
# Epoch 82: val_loss did not improve from 0.13897
#
# Epoch 83: val_loss did not improve from 0.13897
#
# Epoch 84: val_loss did not improve from 0.13897
#
# Epoch 85: val_loss did not improve from 0.13897
#
# Epoch 86: val_loss did not improve from 0.13897
#
# Epoch 87: val_loss did not improve from 0.13897
#
# Epoch 88: val_loss did not improve from 0.13897
#
# Epoch 89: val_loss did not improve from 0.13897
#
# Epoch 90: val_loss did not improve from 0.13897
#
# Epoch 91: val_loss did not improve from 0.13897
#
# Epoch 92: val_loss did not improve from 0.13897
#
# Epoch 93: val_loss did not improve from 0.13897
#
# Epoch 94: val_loss did not improve from 0.13897
#
# Epoch 95: val_loss did not improve from 0.13897
#
# Epoch 96: val_loss did not improve from 0.13897
#
# Epoch 97: val_loss did not improve from 0.13897
#
# Epoch 98: val_loss did not improve from 0.13897
#
# Epoch 99: val_loss did not improve from 0.13897
#
# Epoch 100: val_loss did not improve from 0.13897
# Analyze using Gradient
# Analyze using LRP-Z
# Analyze using LRP-Epsilon
# Analyze using LRP-Alpha-1-Beta-0
# Lag: 120 days, for Theta
# 2023-10-19 14:22:42.639141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38251 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2023-10-19 14:22:42.640948: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38251 MB memory:  -> device: 1, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# 2023-10-19 14:22:42.642771: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 38251 MB memory:  -> device: 2, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:e2:00.0, compute capability: 8.0
# Epoch 1: val_loss improved from inf to 0.47056, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 2: val_loss did not improve from 0.47056
#
# Epoch 3: val_loss improved from 0.47056 to 0.23590, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 4: val_loss did not improve from 0.23590
#
# Epoch 5: val_loss did not improve from 0.23590
#
# Epoch 6: val_loss did not improve from 0.23590
#
# Epoch 7: val_loss did not improve from 0.23590
#
# Epoch 8: val_loss improved from 0.23590 to 0.23054, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 9: val_loss did not improve from 0.23054
#
# Epoch 10: val_loss did not improve from 0.23054
#
# Epoch 11: val_loss did not improve from 0.23054
#
# Epoch 12: val_loss did not improve from 0.23054
#
# Epoch 13: val_loss did not improve from 0.23054
#
# Epoch 14: val_loss did not improve from 0.23054
#
# Epoch 15: val_loss did not improve from 0.23054
#
# Epoch 16: val_loss did not improve from 0.23054
#
# Epoch 17: val_loss did not improve from 0.23054
#
# Epoch 18: val_loss did not improve from 0.23054
#
# Epoch 19: val_loss did not improve from 0.23054
#
# Epoch 20: val_loss did not improve from 0.23054
#
# Epoch 21: val_loss did not improve from 0.23054
#
# Epoch 22: val_loss did not improve from 0.23054
#
# Epoch 23: val_loss did not improve from 0.23054
#
# Epoch 24: val_loss did not improve from 0.23054
#
# Epoch 25: val_loss did not improve from 0.23054
#
# Epoch 26: val_loss did not improve from 0.23054
#
# Epoch 27: val_loss did not improve from 0.23054
#
# Epoch 28: val_loss did not improve from 0.23054
#
# Epoch 29: val_loss did not improve from 0.23054
#
# Epoch 30: val_loss did not improve from 0.23054
#
# Epoch 31: val_loss did not improve from 0.23054
#
# Epoch 32: val_loss did not improve from 0.23054
#
# Epoch 33: val_loss did not improve from 0.23054
#
# Epoch 34: val_loss did not improve from 0.23054
#
# Epoch 35: val_loss did not improve from 0.23054
#
# Epoch 36: val_loss did not improve from 0.23054
#
# Epoch 37: val_loss did not improve from 0.23054
#
# Epoch 38: val_loss did not improve from 0.23054
#
# Epoch 39: val_loss did not improve from 0.23054
#
# Epoch 40: val_loss did not improve from 0.23054
#
# Epoch 41: val_loss did not improve from 0.23054
#
# Epoch 42: val_loss did not improve from 0.23054
#
# Epoch 43: val_loss did not improve from 0.23054
#
# Epoch 44: val_loss did not improve from 0.23054
#
# Epoch 45: val_loss did not improve from 0.23054
#
# Epoch 46: val_loss did not improve from 0.23054
#
# Epoch 47: val_loss did not improve from 0.23054
#
# Epoch 48: val_loss did not improve from 0.23054
#
# Epoch 49: val_loss did not improve from 0.23054
#
# Epoch 50: val_loss did not improve from 0.23054
#
# Epoch 51: val_loss did not improve from 0.23054
#
# Epoch 52: val_loss did not improve from 0.23054
#
# Epoch 53: val_loss did not improve from 0.23054
#
# Epoch 54: val_loss did not improve from 0.23054
#
# Epoch 55: val_loss did not improve from 0.23054
#
# Epoch 56: val_loss did not improve from 0.23054
#
# Epoch 57: val_loss did not improve from 0.23054
#
# Epoch 58: val_loss did not improve from 0.23054
#
# Epoch 59: val_loss did not improve from 0.23054
#
# Epoch 60: val_loss did not improve from 0.23054
#
# Epoch 61: val_loss did not improve from 0.23054
#
# Epoch 62: val_loss improved from 0.23054 to 0.22908, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 63: val_loss improved from 0.22908 to 0.22417, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 64: val_loss did not improve from 0.22417
#
# Epoch 65: val_loss did not improve from 0.22417
#
# Epoch 66: val_loss did not improve from 0.22417
#
# Epoch 67: val_loss did not improve from 0.22417
#
# Epoch 68: val_loss did not improve from 0.22417
#
# Epoch 69: val_loss did not improve from 0.22417
#
# Epoch 70: val_loss did not improve from 0.22417
#
# Epoch 71: val_loss did not improve from 0.22417
#
# Epoch 72: val_loss did not improve from 0.22417
#
# Epoch 73: val_loss did not improve from 0.22417
#
# Epoch 74: val_loss did not improve from 0.22417
#
# Epoch 75: val_loss did not improve from 0.22417
#
# Epoch 76: val_loss did not improve from 0.22417
#
# Epoch 77: val_loss did not improve from 0.22417
#
# Epoch 78: val_loss did not improve from 0.22417
#
# Epoch 79: val_loss did not improve from 0.22417
#
# Epoch 80: val_loss did not improve from 0.22417
#
# Epoch 81: val_loss did not improve from 0.22417
#
# Epoch 82: val_loss did not improve from 0.22417
#
# Epoch 83: val_loss did not improve from 0.22417
#
# Epoch 84: val_loss did not improve from 0.22417
#
# Epoch 85: val_loss did not improve from 0.22417
#
# Epoch 86: val_loss did not improve from 0.22417
#
# Epoch 87: val_loss did not improve from 0.22417
#
# Epoch 88: val_loss did not improve from 0.22417
#
# Epoch 89: val_loss did not improve from 0.22417
#
# Epoch 90: val_loss did not improve from 0.22417
#
# Epoch 91: val_loss did not improve from 0.22417
#
# Epoch 92: val_loss did not improve from 0.22417
#
# Epoch 93: val_loss did not improve from 0.22417
#
# Epoch 94: val_loss did not improve from 0.22417
#
# Epoch 95: val_loss did not improve from 0.22417
#
# Epoch 96: val_loss did not improve from 0.22417
#
# Epoch 97: val_loss did not improve from 0.22417
#
# Epoch 98: val_loss did not improve from 0.22417
#
# Epoch 99: val_loss did not improve from 0.22417
#
# Epoch 100: val_loss did not improve from 0.22417
# Analyze using Gradient
# Analyze using LRP-Z
# Analyze using LRP-Epsilon
# Analyze using LRP-Alpha-1-Beta-0
# Lag: 180 days, for Theta
# 2023-10-19 14:35:27.788715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38251 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2023-10-19 14:35:27.790522: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38251 MB memory:  -> device: 1, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# 2023-10-19 14:35:27.792346: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 38251 MB memory:  -> device: 2, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:e2:00.0, compute capability: 8.0
# Epoch 1: val_loss improved from inf to 0.16835, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 2: val_loss did not improve from 0.16835
#
# Epoch 3: val_loss improved from 0.16835 to 0.13597, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 4: val_loss improved from 0.13597 to 0.12454, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 5: val_loss did not improve from 0.12454
#
# Epoch 6: val_loss improved from 0.12454 to 0.08953, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 7: val_loss did not improve from 0.08953
#
# Epoch 8: val_loss did not improve from 0.08953
#
# Epoch 9: val_loss did not improve from 0.08953
#
# Epoch 10: val_loss did not improve from 0.08953
#
# Epoch 11: val_loss did not improve from 0.08953
#
# Epoch 12: val_loss did not improve from 0.08953
#
# Epoch 13: val_loss did not improve from 0.08953
#
# Epoch 14: val_loss did not improve from 0.08953
#
# Epoch 15: val_loss did not improve from 0.08953
#
# Epoch 16: val_loss did not improve from 0.08953
#
# Epoch 17: val_loss did not improve from 0.08953
#
# Epoch 18: val_loss did not improve from 0.08953
#
# Epoch 19: val_loss did not improve from 0.08953
#
# Epoch 20: val_loss improved from 0.08953 to 0.08850, saving model to /home1/07665/shrey911/XAIRT/examples/model.h5
#
# Epoch 21: val_loss did not improve from 0.08850
#
# Epoch 22: val_loss did not improve from 0.08850
#
# Epoch 23: val_loss did not improve from 0.08850
#
# Epoch 24: val_loss did not improve from 0.08850
#
# Epoch 25: val_loss did not improve from 0.08850
#
# Epoch 26: val_loss did not improve from 0.08850
#
# Epoch 27: val_loss did not improve from 0.08850
#
# Epoch 28: val_loss did not improve from 0.08850
#
# Epoch 29: val_loss did not improve from 0.08850
#
# Epoch 30: val_loss did not improve from 0.08850
#
# Epoch 31: val_loss did not improve from 0.08850
#
# Epoch 32: val_loss did not improve from 0.08850
#
# Epoch 33: val_loss did not improve from 0.08850
#
# Epoch 34: val_loss did not improve from 0.08850
#
# Epoch 35: val_loss did not improve from 0.08850
#
# Epoch 36: val_loss did not improve from 0.08850
#
# Epoch 37: val_loss did not improve from 0.08850
#
# Epoch 38: val_loss did not improve from 0.08850
#
# Epoch 39: val_loss did not improve from 0.08850
#
# Epoch 40: val_loss did not improve from 0.08850
#
# Epoch 41: val_loss did not improve from 0.08850
#
# Epoch 42: val_loss did not improve from 0.08850
#
# Epoch 43: val_loss did not improve from 0.08850
#
# Epoch 44: val_loss did not improve from 0.08850
#
# Epoch 45: val_loss did not improve from 0.08850
#
# Epoch 46: val_loss did not improve from 0.08850
#
# Epoch 47: val_loss did not improve from 0.08850
#
# Epoch 48: val_loss did not improve from 0.08850
#
# Epoch 49: val_loss did not improve from 0.08850
#
# Epoch 50: val_loss did not improve from 0.08850
#
# Epoch 51: val_loss did not improve from 0.08850
#
# Epoch 52: val_loss did not improve from 0.08850
#
# Epoch 53: val_loss did not improve from 0.08850
#
# Epoch 54: val_loss did not improve from 0.08850
#
# Epoch 55: val_loss did not improve from 0.08850
#
# Epoch 56: val_loss did not improve from 0.08850
#
# Epoch 57: val_loss did not improve from 0.08850
#
# Epoch 58: val_loss did not improve from 0.08850
#
# Epoch 59: val_loss did not improve from 0.08850
#
# Epoch 60: val_loss did not improve from 0.08850
#
# Epoch 61: val_loss did not improve from 0.08850
#
# Epoch 62: val_loss did not improve from 0.08850
#
# Epoch 63: val_loss did not improve from 0.08850
#
# Epoch 64: val_loss did not improve from 0.08850
#
# Epoch 65: val_loss did not improve from 0.08850
#
# Epoch 66: val_loss did not improve from 0.08850
#
# Epoch 67: val_loss did not improve from 0.08850
#
# Epoch 68: val_loss did not improve from 0.08850
#
# Epoch 69: val_loss did not improve from 0.08850
#
# Epoch 70: val_loss did not improve from 0.08850
#
# Epoch 71: val_loss did not improve from 0.08850
#
# Epoch 72: val_loss did not improve from 0.08850
#
# Epoch 73: val_loss did not improve from 0.08850
#
# Epoch 74: val_loss did not improve from 0.08850
#
# Epoch 75: val_loss did not improve from 0.08850
#
# Epoch 76: val_loss did not improve from 0.08850
#
# Epoch 77: val_loss did not improve from 0.08850
#
# Epoch 78: val_loss did not improve from 0.08850
#
# Epoch 79: val_loss did not improve from 0.08850
#
# Epoch 80: val_loss did not improve from 0.08850
#
# Epoch 81: val_loss did not improve from 0.08850
#
# Epoch 82: val_loss did not improve from 0.08850
#
# Epoch 83: val_loss did not improve from 0.08850
#
# Epoch 84: val_loss did not improve from 0.08850
#
# Epoch 85: val_loss did not improve from 0.08850
#
# Epoch 86: val_loss did not improve from 0.08850
#
# Epoch 87: val_loss did not improve from 0.08850
#
# Epoch 88: val_loss did not improve from 0.08850
#
# Epoch 89: val_loss did not improve from 0.08850
#
# Epoch 90: val_loss did not improve from 0.08850
#
# Epoch 91: val_loss did not improve from 0.08850
#
# Epoch 92: val_loss did not improve from 0.08850
#
# Epoch 93: val_loss did not improve from 0.08850
#
# Epoch 94: val_loss did not improve from 0.08850
#
# Epoch 95: val_loss did not improve from 0.08850
#
# Epoch 96: val_loss did not improve from 0.08850
#
# Epoch 97: val_loss did not improve from 0.08850
#
# Epoch 98: val_loss did not improve from 0.08850
#
# Epoch 99: val_loss did not improve from 0.08850
#
# Epoch 100: val_loss did not improve from 0.08850
# Analyze using Gradient
# Analyze using LRP-Z
# Analyze using LRP-Epsilon
# Analyze using LRP-Alpha-1-Beta-0

# %%
for method in methods:

    plt.rcParams["figure.figsize"] = (20,10)
    
    field = np.nanmean(LRPDict_theta['LRP-60'][method['name']], axis=(0,1))
    field = field / np.nanmax(np.abs(field))
    
    P = ecco.plot_proj_to_latlon_grid(ds.XC, ds.YC,
                                  field,
                                  plot_type = 'contourf',
                                  show_colorbar=True, cmap='RdBu_r', cmin = -1, cmax = 1,
                                  user_lon_0 = -150,
                                  dx=2, dy=2, projection_type = 'robin',
                                  less_output = True, subplot_grid = [2,3,1])
    
    P[1].set_title(f"{method['title']} lag -60 days")
    
    field = np.nanmean(LRPDict_theta['LRP0'][method['name']], axis=(0,1))
    field = field / np.nanmax(np.abs(field))
    
    P = ecco.plot_proj_to_latlon_grid(ds.XC, ds.YC,
                                  field,
                                  plot_type = 'contourf',
                                  show_colorbar=True, cmap='RdBu_r', cmin = -1, cmax = 1,
                                  user_lon_0 = -150,
                                  dx=2, dy=2, projection_type = 'robin',
                                  less_output = True, subplot_grid = [2,3,2])
    
    P[1].set_title(f"{method['title']} lag 0 days")
    
    field = np.nanmean(LRPDict_theta['LRP60'][method['name']], axis=(0,1))
    field = field / np.nanmax(np.abs(field))
    
    P = ecco.plot_proj_to_latlon_grid(ds.XC, ds.YC,
                                  field,
                                  plot_type = 'contourf',
                                  user_lon_0 = -150,
                                  show_colorbar=True, cmap='RdBu_r', cmin = -1, cmax = 1,
                                  dx=2, dy=2, projection_type = 'robin',
                                  less_output = True, subplot_grid = [2,3,3])
    
    P[1].set_title(f"{method['title']} lag 60 days")
    
    field = np.nanmean(LRPDict_theta['LRP120'][method['name']], axis=(0,1))
    field = field / np.nanmax(np.abs(field))
    
    P = ecco.plot_proj_to_latlon_grid(ds.XC, ds.YC,
                                  field,
                                  plot_type = 'contourf',
                                  show_colorbar=True, cmap='RdBu_r', cmin = -1, cmax = 1,
                                  user_lon_0 = -150,
                                  dx=2, dy=2, projection_type = 'robin',
                                  less_output = True, subplot_grid = [2,3,4])
    
    P[1].set_title(f"{method['title']} lag 120 days")
    
    field = np.nanmean(LRPDict_theta['LRP180'][method['name']], axis=(0,1))
    field = field / np.nanmax(np.abs(field))
    
    P = ecco.plot_proj_to_latlon_grid(ds.XC, ds.YC,
                                  field,
                                  plot_type = 'contourf',
                                  show_colorbar=True, cmap='RdBu_r', cmin = -1, cmax = 1,
                                  user_lon_0 = -150,
                                  dx=2, dy=2, projection_type = 'robin',
                                  less_output = True, subplot_grid = [2,3,5])
    
    P[1].set_title(f"{method['title']} lag 180 days")
    
    field = np.nanmean(LRPDict_theta['LRP180'][method['name']], axis=(0,1))
    field = field / np.nanmax(np.abs(field))
    plt.show()

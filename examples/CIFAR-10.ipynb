# %%
import warnings

warnings.simplefilter("ignore")

import pandas as pd
import numpy as np
import xarray as xr
import xmitgcm
from xmitgcm import open_mdsdataset
import ecco_v4_py as ecco

import os

import matplotlib.pyplot as plt
from matplotlib import gridspec
import cartopy.crs as ccrs
import cartopy
import cmocean

import tensorflow as tf
import tensorflow.keras as keras

from tensorflow import optimizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.layers import Input, Activation
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import layers
from sklearn.utils import shuffle
import tensorflow.keras.backend as kbackend
import tensorflow.keras.models
from keras.utils import np_utils
from keras.regularizers import l2

# Loading the CIFAR-10 datasets
from keras.datasets import cifar10

tf.compat.v1.disable_eager_execution()

import innvestigate
import innvestigate.utils as iutils
# Out:
# 2023-02-28 12:17:16.755572: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 12:17:18.797617: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ohpc/pub/libs/gnu/openmpi/netcdf/4.5.0/lib:/opt/ohpc/pub/libs/gnu/openmpi/netcdf-fortran/4.4.4/lib:/opt/ohpc/pub/libs/gnu/openmpi/hdf5/1.10.1/lib:/opt/ohpc/pub/mpi/openmpi-gnu/1.10.7/lib:/opt/ohpc/pub/compiler/gcc/5.4.0/lib64:/home/shreyas/lis-1.4.43/installation/lib:/share/jdk-16.0.1/lib::
# 2023-02-28 12:17:18.797655: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-28 12:17:28.911753: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ohpc/pub/libs/gnu/openmpi/netcdf/4.5.0/lib:/opt/ohpc/pub/libs/gnu/openmpi/netcdf-fortran/4.4.4/lib:/opt/ohpc/pub/libs/gnu/openmpi/hdf5/1.10.1/lib:/opt/ohpc/pub/mpi/openmpi-gnu/1.10.7/lib:/opt/ohpc/pub/compiler/gcc/5.4.0/lib64:/home/shreyas/lis-1.4.43/installation/lib:/share/jdk-16.0.1/lib::
# 2023-02-28 12:17:28.914379: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ohpc/pub/libs/gnu/openmpi/netcdf/4.5.0/lib:/opt/ohpc/pub/libs/gnu/openmpi/netcdf-fortran/4.4.4/lib:/opt/ohpc/pub/libs/gnu/openmpi/hdf5/1.10.1/lib:/opt/ohpc/pub/mpi/openmpi-gnu/1.10.7/lib:/opt/ohpc/pub/compiler/gcc/5.4.0/lib64:/home/shreyas/lis-1.4.43/installation/lib:/share/jdk-16.0.1/lib::
# 2023-02-28 12:17:28.914403: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# Declare variables

batch_size = 32 
# 32 examples in a mini-batch, smaller batch size means more updates in one epoch

num_classes = 10 #
class_names = ['airplanes', 'cars', 'birds', 'cats', 'deer', 'dogs', 'frogs', 'horses', 'ships', 'trucks']
epochs = 100 # repeat 100 times

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data() 

classes_train = np.array([class_names[y[0]] for y in y_train])
classes_train = classes_train[:,np.newaxis]
classes_test = np.array([class_names[y[0]] for y in y_test])
classes_test = classes_test[:,np.newaxis]

# %%
plot_cols = 5
plot_rows = num_classes

plt.rcParams['figure.figsize'] = [10, 20]
fig, ax = plt.subplots(plot_rows,plot_cols)
fig.subplots_adjust(hspace=0, wspace=0)

for i in range(plot_rows):

    class_samples = x_train[np.squeeze(y_train)==i]
    shuffled_indices = np.arange(class_samples.shape[0])
    np.random.shuffle(shuffled_indices)
    plot_samples = class_samples[shuffled_indices[:plot_cols]]

    for j in range(plot_cols):
        
        ax[i, j].imshow(plot_samples[j])
        ax[i, j].set_xticklabels([])
        ax[i, j].set_yticklabels([])
        ax[i, j].tick_params(left=False)
        ax[i, j].tick_params(bottom=False)
        if j == 0:
            ax[i, j].set_ylabel(class_names[i])
            ### Remove borders
            ax[i, j].spines['top'].set_visible(False)
            ax[i, j].spines['right'].set_visible(False)
            ax[i, j].spines['bottom'].set_visible(False)
            ax[i, j].spines['left'].set_visible(False)
        else:
            ax[i, j].axis('off')
        
plt.show()

# %%
x_train_nom = x_train.astype(np.float) / 255.0
x_test_nom  = x_test.astype(np.float) / 255.0
y_train_onehot = keras.utils.to_categorical(y_train)
y_test_onehot = keras.utils.to_categorical(y_test)

# %%
keras.backend.clear_session()

inputs = Input(shape=(32,32,3))
conv2d1 = Conv2D(filters=32,kernel_size=(4,4),input_shape=(32,32,3),activation='relu', kernel_regularizer=l2(0.001))
maxpool2d = MaxPooling2D(pool_size=(2,2))
dropout = Dropout(0.2)
conv2d2 = Conv2D(filters=64,kernel_size=(4,4),input_shape=(14,14,32),activation='relu', kernel_regularizer=l2(0.001))
flatten = Flatten()
dense1 = Dense(256, activation='relu', kernel_regularizer=l2(0.001))
dense2 = Dense(10, activation='softmax')

x = conv2d1(inputs)
print(x.shape)
x = maxpool2d(x)
x = dropout(x)
print(x.shape)
x = conv2d2(x)
print(x.shape)
x = maxpool2d(x)
x = dropout(x)
print(x.shape)
x = flatten(x)
print(x.shape)
x = dense1(x)
x = dropout(x)
print(x.shape)
x = dense2(x)
print(x.shape)

model1 = keras.Model(inputs=inputs, outputs=x) 

mod_h5_1 = 'CIFAR10_model_1.h5'

checkpoint = ModelCheckpoint(mod_h5_1, monitor='val_loss',
                             verbose=1,save_best_only=True)
        
callbacks = [checkpoint]
model1.compile(optimizer='adam',
            loss='categorical_crossentropy', metrics=['acc'])
fit1 = model1.fit(x_train_nom, y_train_onehot,
            batch_size=1000,
            epochs=100, 
            shuffle=True,
            validation_split = 0.1, 
            callbacks=callbacks)
# Out:
# (None, 29, 29, 32)
# (None, 14, 14, 32)
# (None, 11, 11, 64)
# (None, 5, 5, 64)
# (None, 1600)
# (None, 256)
# (None, 10)
# 2023-02-28 12:17:53.017323: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/ohpc/pub/libs/gnu/openmpi/netcdf/4.5.0/lib:/opt/ohpc/pub/libs/gnu/openmpi/netcdf-fortran/4.4.4/lib:/opt/ohpc/pub/libs/gnu/openmpi/hdf5/1.10.1/lib:/opt/ohpc/pub/mpi/openmpi-gnu/1.10.7/lib:/opt/ohpc/pub/compiler/gcc/5.4.0/lib64:/home/shreyas/lis-1.4.43/installation/lib:/share/jdk-16.0.1/lib::
# 2023-02-28 12:17:53.017549: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-28 12:17:53.017583: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c2-1): /proc/driver/nvidia/version does not exist
# Train on 45000 samples, validate on 5000 samples
# 2023-02-28 12:17:53.819788: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 12:17:53.873242: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# Epoch 1/100
# 2023-02-28 12:17:54.110580: W tensorflow/c/c_api.cc:291] Operation '{name:'training/Adam/conv2d_1/bias/v/Assign' id:437 op device:{requested: '', assigned: ''} def:{{{node training/Adam/conv2d_1/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/conv2d_1/bias/v, training/Adam/conv2d_1/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 45000/45000 [==============================] - ETA: 0s - loss: 2.2964 - acc: 0.2796
# 2023-02-28 12:18:02.016263: W tensorflow/c/c_api.cc:291] Operation '{name:'loss/AddN_1' id:233 op device:{requested: '', assigned: ''} def:{{{node loss/AddN_1}} = AddN[N=2, T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul, loss/AddN)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 1.92860, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 185us/sample - loss: 2.2964 - acc: 0.2796 - val_loss: 1.9286 - val_acc: 0.3878
# Epoch 2/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.8340 - acc: 0.4080
# Epoch 2: val_loss improved from 1.92860 to 1.72531, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 173us/sample - loss: 1.8340 - acc: 0.4080 - val_loss: 1.7253 - val_acc: 0.4420
# Epoch 3/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.6728 - acc: 0.4528
# Epoch 3: val_loss improved from 1.72531 to 1.58535, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 175us/sample - loss: 1.6728 - acc: 0.4528 - val_loss: 1.5853 - val_acc: 0.4972
# Epoch 4/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.5839 - acc: 0.4846
# Epoch 4: val_loss improved from 1.58535 to 1.51486, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 175us/sample - loss: 1.5839 - acc: 0.4846 - val_loss: 1.5149 - val_acc: 0.5214
# Epoch 5/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.5157 - acc: 0.5074
# Epoch 5: val_loss improved from 1.51486 to 1.48704, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 177us/sample - loss: 1.5157 - acc: 0.5074 - val_loss: 1.4870 - val_acc: 0.5328
# Epoch 6/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.4633 - acc: 0.5266
# Epoch 6: val_loss improved from 1.48704 to 1.41366, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 174us/sample - loss: 1.4633 - acc: 0.5266 - val_loss: 1.4137 - val_acc: 0.5460
# Epoch 7/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.4183 - acc: 0.5423
# Epoch 7: val_loss improved from 1.41366 to 1.34997, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 174us/sample - loss: 1.4183 - acc: 0.5423 - val_loss: 1.3500 - val_acc: 0.5832
# Epoch 8/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.3802 - acc: 0.5579
# Epoch 8: val_loss did not improve from 1.34997
# 45000/45000 [==============================] - 8s 173us/sample - loss: 1.3802 - acc: 0.5579 - val_loss: 1.3514 - val_acc: 0.5734
# Epoch 9/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.3480 - acc: 0.5718
# Epoch 9: val_loss improved from 1.34997 to 1.29807, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 174us/sample - loss: 1.3480 - acc: 0.5718 - val_loss: 1.2981 - val_acc: 0.5966
# Epoch 10/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.3278 - acc: 0.5790
# Epoch 10: val_loss improved from 1.29807 to 1.25681, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 174us/sample - loss: 1.3278 - acc: 0.5790 - val_loss: 1.2568 - val_acc: 0.6184
# Epoch 11/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2947 - acc: 0.5922
# Epoch 11: val_loss improved from 1.25681 to 1.23174, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 174us/sample - loss: 1.2947 - acc: 0.5922 - val_loss: 1.2317 - val_acc: 0.6210
# Epoch 12/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2769 - acc: 0.5963
# Epoch 12: val_loss did not improve from 1.23174
# 45000/45000 [==============================] - 7s 165us/sample - loss: 1.2769 - acc: 0.5963 - val_loss: 1.2393 - val_acc: 0.6140
# Epoch 13/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2729 - acc: 0.6024
# Epoch 13: val_loss did not improve from 1.23174
# 45000/45000 [==============================] - 8s 171us/sample - loss: 1.2729 - acc: 0.6024 - val_loss: 1.2403 - val_acc: 0.6158
# Epoch 14/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2431 - acc: 0.6121
# Epoch 14: val_loss improved from 1.23174 to 1.20895, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 171us/sample - loss: 1.2431 - acc: 0.6121 - val_loss: 1.2090 - val_acc: 0.6264
# Epoch 15/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2292 - acc: 0.6172
# Epoch 15: val_loss improved from 1.20895 to 1.17196, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 173us/sample - loss: 1.2292 - acc: 0.6172 - val_loss: 1.1720 - val_acc: 0.6470
# Epoch 16/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2141 - acc: 0.6245
# Epoch 16: val_loss improved from 1.17196 to 1.16469, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 174us/sample - loss: 1.2141 - acc: 0.6245 - val_loss: 1.1647 - val_acc: 0.6496
# Epoch 17/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2042 - acc: 0.6301
# Epoch 17: val_loss improved from 1.16469 to 1.15044, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 9s 191us/sample - loss: 1.2042 - acc: 0.6301 - val_loss: 1.1504 - val_acc: 0.6598
# Epoch 18/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1857 - acc: 0.6363
# Epoch 18: val_loss did not improve from 1.15044
# 45000/45000 [==============================] - 8s 172us/sample - loss: 1.1857 - acc: 0.6363 - val_loss: 1.1538 - val_acc: 0.6546
# Epoch 19/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1787 - acc: 0.6407
# Epoch 19: val_loss improved from 1.15044 to 1.13199, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 167us/sample - loss: 1.1787 - acc: 0.6407 - val_loss: 1.1320 - val_acc: 0.6578
# Epoch 20/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1658 - acc: 0.6437
# Epoch 20: val_loss improved from 1.13199 to 1.11199, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 171us/sample - loss: 1.1658 - acc: 0.6437 - val_loss: 1.1120 - val_acc: 0.6690
# Epoch 21/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1538 - acc: 0.6477
# Epoch 21: val_loss did not improve from 1.11199
# 45000/45000 [==============================] - 8s 174us/sample - loss: 1.1538 - acc: 0.6477 - val_loss: 1.1245 - val_acc: 0.6604
# Epoch 22/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1468 - acc: 0.6535
# Epoch 22: val_loss improved from 1.11199 to 1.09437, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 171us/sample - loss: 1.1468 - acc: 0.6535 - val_loss: 1.0944 - val_acc: 0.6802
# Epoch 23/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1379 - acc: 0.6551
# Epoch 23: val_loss did not improve from 1.09437
# 45000/45000 [==============================] - 8s 170us/sample - loss: 1.1379 - acc: 0.6551 - val_loss: 1.1007 - val_acc: 0.6758
# Epoch 24/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1204 - acc: 0.6637
# Epoch 24: val_loss improved from 1.09437 to 1.07569, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 7s 164us/sample - loss: 1.1204 - acc: 0.6637 - val_loss: 1.0757 - val_acc: 0.6838
# Epoch 25/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1215 - acc: 0.6607
# Epoch 25: val_loss did not improve from 1.07569
# 45000/45000 [==============================] - 8s 171us/sample - loss: 1.1215 - acc: 0.6607 - val_loss: 1.0932 - val_acc: 0.6744
# Epoch 26/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1035 - acc: 0.6693
# Epoch 26: val_loss improved from 1.07569 to 1.07378, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 175us/sample - loss: 1.1035 - acc: 0.6693 - val_loss: 1.0738 - val_acc: 0.6900
# Epoch 27/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0932 - acc: 0.6734
# Epoch 27: val_loss improved from 1.07378 to 1.05830, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 170us/sample - loss: 1.0932 - acc: 0.6734 - val_loss: 1.0583 - val_acc: 0.6954
# Epoch 28/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0875 - acc: 0.6762
# Epoch 28: val_loss improved from 1.05830 to 1.05148, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 174us/sample - loss: 1.0875 - acc: 0.6762 - val_loss: 1.0515 - val_acc: 0.6998
# Epoch 29/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0765 - acc: 0.6822
# Epoch 29: val_loss did not improve from 1.05148
# 45000/45000 [==============================] - 8s 184us/sample - loss: 1.0765 - acc: 0.6822 - val_loss: 1.0600 - val_acc: 0.6984
# Epoch 30/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0741 - acc: 0.6840
# Epoch 30: val_loss improved from 1.05148 to 1.04646, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 175us/sample - loss: 1.0741 - acc: 0.6840 - val_loss: 1.0465 - val_acc: 0.7046
# Epoch 31/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0700 - acc: 0.6852
# Epoch 31: val_loss did not improve from 1.04646
# 45000/45000 [==============================] - 8s 171us/sample - loss: 1.0700 - acc: 0.6852 - val_loss: 1.0523 - val_acc: 0.6976
# Epoch 32/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0525 - acc: 0.6912
# Epoch 32: val_loss improved from 1.04646 to 1.03125, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 175us/sample - loss: 1.0525 - acc: 0.6912 - val_loss: 1.0313 - val_acc: 0.7028
# Epoch 33/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0514 - acc: 0.6928
# Epoch 33: val_loss did not improve from 1.03125
# 45000/45000 [==============================] - 8s 178us/sample - loss: 1.0514 - acc: 0.6928 - val_loss: 1.0370 - val_acc: 0.7026
# Epoch 34/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0449 - acc: 0.6988
# Epoch 34: val_loss did not improve from 1.03125
# 45000/45000 [==============================] - 8s 175us/sample - loss: 1.0449 - acc: 0.6988 - val_loss: 1.0471 - val_acc: 0.7028
# Epoch 35/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0330 - acc: 0.7029
# Epoch 35: val_loss improved from 1.03125 to 1.03068, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 170us/sample - loss: 1.0330 - acc: 0.7029 - val_loss: 1.0307 - val_acc: 0.7148
# Epoch 36/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0287 - acc: 0.7008
# Epoch 36: val_loss did not improve from 1.03068
# 45000/45000 [==============================] - 8s 173us/sample - loss: 1.0287 - acc: 0.7008 - val_loss: 1.0310 - val_acc: 0.7124
# Epoch 37/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0263 - acc: 0.7029
# Epoch 37: val_loss improved from 1.03068 to 1.02409, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 173us/sample - loss: 1.0263 - acc: 0.7029 - val_loss: 1.0241 - val_acc: 0.7162
# Epoch 38/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0214 - acc: 0.7069
# Epoch 38: val_loss improved from 1.02409 to 1.00141, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 177us/sample - loss: 1.0214 - acc: 0.7069 - val_loss: 1.0014 - val_acc: 0.7254
# Epoch 39/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0064 - acc: 0.7131
# Epoch 39: val_loss did not improve from 1.00141
# 45000/45000 [==============================] - 8s 172us/sample - loss: 1.0064 - acc: 0.7131 - val_loss: 1.0120 - val_acc: 0.7126
# Epoch 40/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0001 - acc: 0.7154
# Epoch 40: val_loss did not improve from 1.00141
# 45000/45000 [==============================] - 8s 172us/sample - loss: 1.0001 - acc: 0.7154 - val_loss: 1.0041 - val_acc: 0.7190
# Epoch 41/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9914 - acc: 0.7180
# Epoch 41: val_loss improved from 1.00141 to 0.99209, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 176us/sample - loss: 0.9914 - acc: 0.7180 - val_loss: 0.9921 - val_acc: 0.7216
# Epoch 42/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9974 - acc: 0.7169
# Epoch 42: val_loss did not improve from 0.99209
# 45000/45000 [==============================] - 8s 168us/sample - loss: 0.9974 - acc: 0.7169 - val_loss: 0.9963 - val_acc: 0.7232
# Epoch 43/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9869 - acc: 0.7207
# Epoch 43: val_loss did not improve from 0.99209
# 45000/45000 [==============================] - 7s 167us/sample - loss: 0.9869 - acc: 0.7207 - val_loss: 1.0010 - val_acc: 0.7230
# Epoch 44/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9815 - acc: 0.7242
# Epoch 44: val_loss improved from 0.99209 to 0.98945, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 176us/sample - loss: 0.9815 - acc: 0.7242 - val_loss: 0.9894 - val_acc: 0.7238
# Epoch 45/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9754 - acc: 0.7251
# Epoch 45: val_loss improved from 0.98945 to 0.97788, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 186us/sample - loss: 0.9754 - acc: 0.7251 - val_loss: 0.9779 - val_acc: 0.7352
# Epoch 46/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9731 - acc: 0.7277
# Epoch 46: val_loss did not improve from 0.97788
# 45000/45000 [==============================] - 8s 182us/sample - loss: 0.9731 - acc: 0.7277 - val_loss: 0.9887 - val_acc: 0.7286
# Epoch 47/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9659 - acc: 0.7292
# Epoch 47: val_loss did not improve from 0.97788
# 45000/45000 [==============================] - 8s 178us/sample - loss: 0.9659 - acc: 0.7292 - val_loss: 0.9841 - val_acc: 0.7384
# Epoch 48/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9619 - acc: 0.7327
# Epoch 48: val_loss did not improve from 0.97788
# 45000/45000 [==============================] - 8s 176us/sample - loss: 0.9619 - acc: 0.7327 - val_loss: 0.9795 - val_acc: 0.7326
# Epoch 49/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9557 - acc: 0.7343
# Epoch 49: val_loss did not improve from 0.97788
# 45000/45000 [==============================] - 8s 183us/sample - loss: 0.9557 - acc: 0.7343 - val_loss: 0.9813 - val_acc: 0.7352
# Epoch 50/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9412 - acc: 0.7404
# Epoch 50: val_loss did not improve from 0.97788
# 45000/45000 [==============================] - 8s 170us/sample - loss: 0.9412 - acc: 0.7404 - val_loss: 0.9783 - val_acc: 0.7352
# Epoch 51/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9431 - acc: 0.7389
# Epoch 51: val_loss did not improve from 0.97788
# 45000/45000 [==============================] - 8s 169us/sample - loss: 0.9431 - acc: 0.7389 - val_loss: 0.9808 - val_acc: 0.7322
# Epoch 52/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9480 - acc: 0.7390
# Epoch 52: val_loss improved from 0.97788 to 0.96639, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 174us/sample - loss: 0.9480 - acc: 0.7390 - val_loss: 0.9664 - val_acc: 0.7358
# Epoch 53/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9297 - acc: 0.7473
# Epoch 53: val_loss improved from 0.96639 to 0.96450, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 174us/sample - loss: 0.9297 - acc: 0.7473 - val_loss: 0.9645 - val_acc: 0.7366
# Epoch 54/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9364 - acc: 0.7439
# Epoch 54: val_loss did not improve from 0.96450
# 45000/45000 [==============================] - 8s 171us/sample - loss: 0.9364 - acc: 0.7439 - val_loss: 0.9834 - val_acc: 0.7314
# Epoch 55/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9254 - acc: 0.7474
# Epoch 55: val_loss improved from 0.96450 to 0.96114, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 170us/sample - loss: 0.9254 - acc: 0.7474 - val_loss: 0.9611 - val_acc: 0.7420
# Epoch 56/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9226 - acc: 0.7470
# Epoch 56: val_loss did not improve from 0.96114
# 45000/45000 [==============================] - 8s 171us/sample - loss: 0.9226 - acc: 0.7470 - val_loss: 0.9700 - val_acc: 0.7372
# Epoch 57/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9185 - acc: 0.7523
# Epoch 57: val_loss did not improve from 0.96114
# 45000/45000 [==============================] - 8s 173us/sample - loss: 0.9185 - acc: 0.7523 - val_loss: 0.9659 - val_acc: 0.7332
# Epoch 58/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9091 - acc: 0.7544
# Epoch 58: val_loss did not improve from 0.96114
# 45000/45000 [==============================] - 8s 171us/sample - loss: 0.9091 - acc: 0.7544 - val_loss: 0.9669 - val_acc: 0.7432
# Epoch 59/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9038 - acc: 0.7570
# Epoch 59: val_loss did not improve from 0.96114
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.9038 - acc: 0.7570 - val_loss: 0.9747 - val_acc: 0.7360
# Epoch 60/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8983 - acc: 0.7598
# Epoch 60: val_loss improved from 0.96114 to 0.95002, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 173us/sample - loss: 0.8983 - acc: 0.7598 - val_loss: 0.9500 - val_acc: 0.7498
# Epoch 61/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9055 - acc: 0.7562
# Epoch 61: val_loss did not improve from 0.95002
# 45000/45000 [==============================] - 8s 171us/sample - loss: 0.9055 - acc: 0.7562 - val_loss: 0.9771 - val_acc: 0.7360
# Epoch 62/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8992 - acc: 0.7604
# Epoch 62: val_loss improved from 0.95002 to 0.94875, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 176us/sample - loss: 0.8992 - acc: 0.7604 - val_loss: 0.9488 - val_acc: 0.7534
# Epoch 63/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8881 - acc: 0.7634
# Epoch 63: val_loss improved from 0.94875 to 0.94645, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.8881 - acc: 0.7634 - val_loss: 0.9465 - val_acc: 0.7532
# Epoch 64/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8860 - acc: 0.7647
# Epoch 64: val_loss did not improve from 0.94645
# 45000/45000 [==============================] - 8s 173us/sample - loss: 0.8860 - acc: 0.7647 - val_loss: 0.9551 - val_acc: 0.7478
# Epoch 65/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8894 - acc: 0.7629
# Epoch 65: val_loss did not improve from 0.94645
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.8894 - acc: 0.7629 - val_loss: 0.9546 - val_acc: 0.7484
# Epoch 66/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8710 - acc: 0.7700
# Epoch 66: val_loss did not improve from 0.94645
# 45000/45000 [==============================] - 8s 174us/sample - loss: 0.8710 - acc: 0.7700 - val_loss: 0.9509 - val_acc: 0.7510
# Epoch 67/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8737 - acc: 0.7708
# Epoch 67: val_loss did not improve from 0.94645
# 45000/45000 [==============================] - 8s 175us/sample - loss: 0.8737 - acc: 0.7708 - val_loss: 0.9475 - val_acc: 0.7492
# Epoch 68/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8685 - acc: 0.7720
# Epoch 68: val_loss did not improve from 0.94645
# 45000/45000 [==============================] - 8s 171us/sample - loss: 0.8685 - acc: 0.7720 - val_loss: 0.9467 - val_acc: 0.7538
# Epoch 69/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8651 - acc: 0.7738
# Epoch 69: val_loss did not improve from 0.94645
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.8651 - acc: 0.7738 - val_loss: 0.9537 - val_acc: 0.7516
# Epoch 70/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8691 - acc: 0.7706
# Epoch 70: val_loss improved from 0.94645 to 0.93972, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 171us/sample - loss: 0.8691 - acc: 0.7706 - val_loss: 0.9397 - val_acc: 0.7510
# Epoch 71/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8551 - acc: 0.7783
# Epoch 71: val_loss did not improve from 0.93972
# 45000/45000 [==============================] - 8s 174us/sample - loss: 0.8551 - acc: 0.7783 - val_loss: 0.9480 - val_acc: 0.7498
# Epoch 72/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8573 - acc: 0.7780
# Epoch 72: val_loss did not improve from 0.93972
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.8573 - acc: 0.7780 - val_loss: 0.9555 - val_acc: 0.7466
# Epoch 73/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8549 - acc: 0.7774
# Epoch 73: val_loss did not improve from 0.93972
# 45000/45000 [==============================] - 8s 170us/sample - loss: 0.8549 - acc: 0.7774 - val_loss: 0.9572 - val_acc: 0.7514
# Epoch 74/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8446 - acc: 0.7817
# Epoch 74: val_loss did not improve from 0.93972
# 45000/45000 [==============================] - 8s 173us/sample - loss: 0.8446 - acc: 0.7817 - val_loss: 0.9569 - val_acc: 0.7470
# Epoch 75/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8454 - acc: 0.7796
# Epoch 75: val_loss did not improve from 0.93972
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.8454 - acc: 0.7796 - val_loss: 0.9526 - val_acc: 0.7524
# Epoch 76/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8447 - acc: 0.7824
# Epoch 76: val_loss did not improve from 0.93972
# 45000/45000 [==============================] - 8s 175us/sample - loss: 0.8447 - acc: 0.7824 - val_loss: 0.9485 - val_acc: 0.7580
# Epoch 77/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8368 - acc: 0.7849
# Epoch 77: val_loss did not improve from 0.93972
# 45000/45000 [==============================] - 8s 180us/sample - loss: 0.8368 - acc: 0.7849 - val_loss: 0.9399 - val_acc: 0.7608
# Epoch 78/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8439 - acc: 0.7844
# Epoch 78: val_loss did not improve from 0.93972
# 45000/45000 [==============================] - 8s 174us/sample - loss: 0.8439 - acc: 0.7844 - val_loss: 0.9560 - val_acc: 0.7576
# Epoch 79/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8411 - acc: 0.7842
# Epoch 79: val_loss did not improve from 0.93972
# 45000/45000 [==============================] - 8s 173us/sample - loss: 0.8411 - acc: 0.7842 - val_loss: 0.9603 - val_acc: 0.7512
# Epoch 80/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8302 - acc: 0.7891
# Epoch 80: val_loss did not improve from 0.93972
# 45000/45000 [==============================] - 8s 174us/sample - loss: 0.8302 - acc: 0.7891 - val_loss: 0.9546 - val_acc: 0.7472
# Epoch 81/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8314 - acc: 0.7869
# Epoch 81: val_loss improved from 0.93972 to 0.93334, saving model to CIFAR10_model_1.h5
# 45000/45000 [==============================] - 8s 176us/sample - loss: 0.8314 - acc: 0.7869 - val_loss: 0.9333 - val_acc: 0.7568
# Epoch 82/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8277 - acc: 0.7894
# Epoch 82: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 174us/sample - loss: 0.8277 - acc: 0.7894 - val_loss: 0.9526 - val_acc: 0.7496
# Epoch 83/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8185 - acc: 0.7926
# Epoch 83: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 173us/sample - loss: 0.8185 - acc: 0.7926 - val_loss: 0.9455 - val_acc: 0.7624
# Epoch 84/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8174 - acc: 0.7937
# Epoch 84: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 173us/sample - loss: 0.8174 - acc: 0.7937 - val_loss: 0.9404 - val_acc: 0.7588
# Epoch 85/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8186 - acc: 0.7964
# Epoch 85: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 175us/sample - loss: 0.8186 - acc: 0.7964 - val_loss: 0.9405 - val_acc: 0.7596
# Epoch 86/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8135 - acc: 0.7960
# Epoch 86: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.8135 - acc: 0.7960 - val_loss: 0.9418 - val_acc: 0.7574
# Epoch 87/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8098 - acc: 0.7988
# Epoch 87: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 171us/sample - loss: 0.8098 - acc: 0.7988 - val_loss: 0.9439 - val_acc: 0.7616
# Epoch 88/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8113 - acc: 0.7958
# Epoch 88: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 171us/sample - loss: 0.8113 - acc: 0.7958 - val_loss: 0.9420 - val_acc: 0.7552
# Epoch 89/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8131 - acc: 0.7977
# Epoch 89: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.8131 - acc: 0.7977 - val_loss: 0.9488 - val_acc: 0.7590
# Epoch 90/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.7984 - acc: 0.8029
# Epoch 90: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.7984 - acc: 0.8029 - val_loss: 0.9433 - val_acc: 0.7592
# Epoch 91/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8059 - acc: 0.8007
# Epoch 91: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.8059 - acc: 0.8007 - val_loss: 0.9403 - val_acc: 0.7616
# Epoch 92/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.7999 - acc: 0.8041
# Epoch 92: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 174us/sample - loss: 0.7999 - acc: 0.8041 - val_loss: 0.9461 - val_acc: 0.7568
# Epoch 93/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8012 - acc: 0.8029
# Epoch 93: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.8012 - acc: 0.8029 - val_loss: 0.9489 - val_acc: 0.7532
# Epoch 94/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.7936 - acc: 0.8046
# Epoch 94: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 173us/sample - loss: 0.7936 - acc: 0.8046 - val_loss: 0.9429 - val_acc: 0.7546
# Epoch 95/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.7913 - acc: 0.8068
# Epoch 95: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 173us/sample - loss: 0.7913 - acc: 0.8068 - val_loss: 0.9554 - val_acc: 0.7512
# Epoch 96/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.7870 - acc: 0.8075
# Epoch 96: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.7870 - acc: 0.8075 - val_loss: 0.9461 - val_acc: 0.7558
# Epoch 97/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.7880 - acc: 0.8080
# Epoch 97: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 172us/sample - loss: 0.7880 - acc: 0.8080 - val_loss: 0.9544 - val_acc: 0.7526
# Epoch 98/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.7817 - acc: 0.8121
# Epoch 98: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 169us/sample - loss: 0.7817 - acc: 0.8121 - val_loss: 0.9504 - val_acc: 0.7578
# Epoch 99/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.7876 - acc: 0.8073
# Epoch 99: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 169us/sample - loss: 0.7876 - acc: 0.8073 - val_loss: 0.9420 - val_acc: 0.7628
# Epoch 100/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.7799 - acc: 0.8094
# Epoch 100: val_loss did not improve from 0.93334
# 45000/45000 [==============================] - 8s 171us/sample - loss: 0.7799 - acc: 0.8094 - val_loss: 0.9444 - val_acc: 0.7616

# %%
keras.backend.clear_session()

inputs = Input(shape=(32,32,3))
conv2d1 = Conv2D(filters=32,kernel_size=(4,4),input_shape=(32,32,3),activation='relu', kernel_regularizer=l2(0.001))
maxpool2d = MaxPooling2D(pool_size=(2,2))
dropout = Dropout(0.2)
conv2d2 = Conv2D(filters=64,kernel_size=(4,4),input_shape=(14,14,32),activation='relu', kernel_regularizer=l2(0.001))
flatten = Flatten()
dense1 = Dense(256, activation='relu', kernel_regularizer=l2(0.001))
dense2 = Dense(10, activation='softmax')

x = conv2d1(inputs)
x = maxpool2d(x)
x = dropout(x)
x = conv2d2(x)
x = maxpool2d(x)
x = dropout(x)
x = flatten(x)
x = dense1(x)
x = dropout(x)
x = dense2(x)

best_model1 = keras.Model(inputs=inputs, outputs=x) 
best_model1.load_weights(mod_h5_1)
best_model1.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['acc'])

y_test_pred1 = best_model1.predict(x_test_nom)
# Out:
# 2023-02-28 12:30:55.044880: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_1/bias/Assign' id:125 op device:{requested: '', assigned: ''} def:{{{node dense_1/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_1/bias, dense_1/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:55.198667: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_1/Softmax' id:131 op device:{requested: '', assigned: ''} def:{{{node dense_1/Softmax}} = Softmax[T=DT_FLOAT, _has_manual_control_dependencies=true](dense_1/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:55.219581: W tensorflow/c/c_api.cc:291] Operation '{name:'count/Assign' id:174 op device:{requested: '', assigned: ''} def:{{{node count/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](count, count/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(fit1.history['loss'], color='b', label="Training Loss")
ax[0].plot(fit1.history['val_loss'], color='r', label="Validation Training Loss")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(fit1.history['acc'], color='b', label="Training Accuracy")
ax[1].plot(fit1.history['val_acc'], color='r', label="Validation Training Accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
score1 = best_model1.evaluate(x_test_nom, y_test_onehot, verbose = 0) 

print('Test loss:', score1[0]) 
print('Test accuracy:', score1[1])
# Out:
# 2023-02-28 12:30:56.659897: W tensorflow/c/c_api.cc:291] Operation '{name:'loss/AddN_1' id:266 op device:{requested: '', assigned: ''} def:{{{node loss/AddN_1}} = AddN[N=2, T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul, loss/AddN)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test loss: 0.9708002155303955
# Test accuracy: 0.7448

# %%
sample_no = 0

best_model1_no_softmax = innvestigate.model_wo_softmax(best_model1)

analyzer_gradient1 = innvestigate.create_analyzer("gradient", best_model1_no_softmax)
a1g = analyzer_gradient1.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a1g = a1g.sum(axis=np.argmax(np.asarray(a1g.shape) == 3))
a1g /= np.max(np.abs(a1g))

analyzer_gradient1 = innvestigate.create_analyzer("input_t_gradient", best_model1_no_softmax)
a1itg = analyzer_gradient1.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a1itg = a1itg.sum(axis=np.argmax(np.asarray(a1itg.shape) == 3))
a1itg /= np.max(np.abs(a1itg))

analyzer_gradient1 = innvestigate.create_analyzer("deep_taylor", best_model1_no_softmax)
a1dt = analyzer_gradient1.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a1dt = a1dt.sum(axis=np.argmax(np.asarray(a1dt.shape) == 3))
a1dt /= np.max(np.abs(a1dt))

analyzer_gradient1 = innvestigate.create_analyzer("integrated_gradients", best_model1_no_softmax)
a1ig = analyzer_gradient1.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a1ig = a1ig.sum(axis=np.argmax(np.asarray(a1ig.shape) == 3))
a1ig /= np.max(np.abs(a1ig))

analyzer_gradient1 = innvestigate.create_analyzer("lrp.z", best_model1_no_softmax)
a1lrpz = analyzer_gradient1.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a1lrpz = a1lrpz.sum(axis=np.argmax(np.asarray(a1lrpz.shape) == 3))
a1lrpz /= np.max(np.abs(a1lrpz))

analyzer_gradient1 = innvestigate.create_analyzer("lrp.epsilon", best_model1_no_softmax)
a1lrpe = analyzer_gradient1.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a1lrpe = a1lrpe.sum(axis=np.argmax(np.asarray(a1lrpe.shape) == 3))
a1lrpe /= np.max(np.abs(a1lrpe))

analyzer_gradient1 = innvestigate.create_analyzer("lrp.alpha_1_beta_0", best_model1_no_softmax)
a1lrpa1b0 = analyzer_gradient1.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a1lrpa1b0 = a1lrpa1b0.sum(axis=np.argmax(np.asarray(a1lrpa1b0.shape) == 3))
a1lrpa1b0 /= np.max(np.abs(a1lrpe))
# Out:
# 2023-02-28 12:30:57.900456: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:57.941455: W tensorflow/c/c_api.cc:291] Operation '{name:'bias/Assign' id:295 op device:{requested: '', assigned: ''} def:{{{node bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](bias, bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:57.994343: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.059394: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.108431: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.146377: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.183682: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.220464: W tensorflow/c/c_api.cc:291] Operation '{name:'dense/MatMul/ReadVariableOp' id:94 op device:{requested: '', assigned: ''} def:{{{node dense/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.256866: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.294037: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_2/MatMul/ReadVariableOp' id:297 op device:{requested: '', assigned: ''} def:{{{node dense_2/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.330967: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:315 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.367368: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:311 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.404256: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:317 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.445635: W tensorflow/c/c_api.cc:291] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:302 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.484132: W tensorflow/c/c_api.cc:291] Operation '{name:'ones_like/Const' id:305 op device:{requested: '', assigned: ''} def:{{{node ones_like/Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.526620: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.576806: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.625350: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:58.677865: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_10/conv2d/Conv2D_grad/Conv2DBackpropInput' id:384 op device:{requested: '', assigned: ''} def:{{{node gradients_10/conv2d/Conv2D_grad/Conv2DBackpropInput}} = Conv2DBackpropInput[T=DT_FLOAT, _class=["loc:@conv2d/Conv2D"], _has_manual_control_dependencies=true, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](gradients_10/conv2d/Conv2D_grad/ShapeN, conv2d/Conv2D/ReadVariableOp, gradients_10/conv2d/Relu_grad/ReluGrad)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:59.569617: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:59.616549: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:59.660834: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:59.740834: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:59.799612: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:59.856266: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:59.912251: W tensorflow/c/c_api.cc:291] Operation '{name:'dense/MatMul/ReadVariableOp' id:94 op device:{requested: '', assigned: ''} def:{{{node dense/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:30:59.967822: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:00.024023: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_2/MatMul/ReadVariableOp' id:297 op device:{requested: '', assigned: ''} def:{{{node dense_2/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:00.082153: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_11/MaxNeuronSelection_1/Max_grad/range' id:421 op device:{requested: '', assigned: ''} def:{{{node gradients_11/MaxNeuronSelection_1/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true](gradients_11/MaxNeuronSelection_1/Max_grad/range/start, gradients_11/MaxNeuronSelection_1/Max_grad/Size, gradients_11/MaxNeuronSelection_1/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:00.137430: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_11/MaxNeuronSelection_1/Max_grad/mod' id:417 op device:{requested: '', assigned: ''} def:{{{node gradients_11/MaxNeuronSelection_1/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true](gradients_11/MaxNeuronSelection_1/Max_grad/add, gradients_11/MaxNeuronSelection_1/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:00.193014: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_11/MaxNeuronSelection_1/Max_grad/ones' id:423 op device:{requested: '', assigned: ''} def:{{{node gradients_11/MaxNeuronSelection_1/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_11/MaxNeuronSelection_1/Max_grad/Shape_1, gradients_11/MaxNeuronSelection_1/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:00.253522: W tensorflow/c/c_api.cc:291] Operation '{name:'MaxNeuronSelection_1/Max/reduction_indices' id:408 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_1/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:00.311062: W tensorflow/c/c_api.cc:291] Operation '{name:'ones_like_1/Const' id:411 op device:{requested: '', assigned: ''} def:{{{node ones_like_1/Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:00.792943: W tensorflow/c/c_api.cc:291] Operation '{name:'kernel_5/Assign' id:616 op device:{requested: '', assigned: ''} def:{{{node kernel_5/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_5, kernel_5/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:00.889728: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_22/MaxNeuronSelection_2/Max_grad/range' id:680 op device:{requested: '', assigned: ''} def:{{{node gradients_22/MaxNeuronSelection_2/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true](gradients_22/MaxNeuronSelection_2/Max_grad/range/start, gradients_22/MaxNeuronSelection_2/Max_grad/Size, gradients_22/MaxNeuronSelection_2/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:00.972614: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_22/MaxNeuronSelection_2/Max_grad/mod' id:676 op device:{requested: '', assigned: ''} def:{{{node gradients_22/MaxNeuronSelection_2/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true](gradients_22/MaxNeuronSelection_2/Max_grad/add, gradients_22/MaxNeuronSelection_2/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.033606: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_22/MaxNeuronSelection_2/Max_grad/ones' id:682 op device:{requested: '', assigned: ''} def:{{{node gradients_22/MaxNeuronSelection_2/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_22/MaxNeuronSelection_2/Max_grad/Shape_1, gradients_22/MaxNeuronSelection_2/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.101998: W tensorflow/c/c_api.cc:291] Operation '{name:'MaxNeuronSelection_2/Max/reduction_indices' id:510 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_2/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.169244: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_8/x' id:709 op device:{requested: '', assigned: ''} def:{{{node mul_8/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.229894: W tensorflow/c/c_api.cc:291] Operation '{name:'Const' id:706 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.298010: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_7' id:643 op device:{requested: '', assigned: ''} def:{{{node mul_7}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_25, Cast_7)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.471645: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_4' id:597 op device:{requested: '', assigned: ''} def:{{{node mul_4}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_19, Cast_4)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.545071: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.620698: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_9/x' id:763 op device:{requested: '', assigned: ''} def:{{{node mul_9/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.686952: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_1' id:760 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.760944: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_5' id:603 op device:{requested: '', assigned: ''} def:{{{node mul_5}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_21, Cast_5)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:01.959308: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_2' id:557 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_15, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.038556: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_2' id:557 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_15, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.117724: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.204298: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_10/x' id:810 op device:{requested: '', assigned: ''} def:{{{node mul_10/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.277347: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_2' id:807 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.358216: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_3' id:563 op device:{requested: '', assigned: ''} def:{{{node mul_3}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_17, Cast_3)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.435573: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_3' id:563 op device:{requested: '', assigned: ''} def:{{{node mul_3}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_17, Cast_3)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.637524: W tensorflow/c/c_api.cc:291] Operation '{name:'mul' id:517 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_11, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.723096: W tensorflow/c/c_api.cc:291] Operation '{name:'mul' id:517 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_11, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.808564: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.898647: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_11/x' id:858 op device:{requested: '', assigned: ''} def:{{{node mul_11/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:02.976804: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_3' id:855 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:03.049662: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_1' id:523 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_13, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:03.115257: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_1' id:523 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_13, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:03.705660: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:03.783390: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:03.857100: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:03.929054: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:04.001040: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:04.074620: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:04.146991: W tensorflow/c/c_api.cc:291] Operation '{name:'dense/MatMul/ReadVariableOp' id:94 op device:{requested: '', assigned: ''} def:{{{node dense/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:04.219366: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:04.291230: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_2/MatMul/ReadVariableOp' id:297 op device:{requested: '', assigned: ''} def:{{{node dense_2/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:04.363161: W tensorflow/c/c_api.cc:291] Operation '{name:'ones_like_2/Const' id:884 op device:{requested: '', assigned: ''} def:{{{node ones_like_2/Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:04.728233: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_2/BiasAdd' id:300 op device:{requested: '', assigned: ''} def:{{{node dense_2/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_2/MatMul, dense_2/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:04.832608: W tensorflow/c/c_api.cc:291] Operation '{name:'Variable/Assign' id:960 op device:{requested: '', assigned: ''} def:{{{node Variable/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](Variable, Variable/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:04.980626: W tensorflow/c/c_api.cc:291] Operation '{name:'multiply_9/mul' id:1113 op device:{requested: '', assigned: ''} def:{{{node multiply_9/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](reduce_mean/Mean, subtract/sub)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:05.474647: W tensorflow/c/c_api.cc:291] Operation '{name:'kernel_10/Assign' id:1153 op device:{requested: '', assigned: ''} def:{{{node kernel_10/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_10, kernel_10/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:05.690595: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_49/MaxNeuronSelection_3/Max_grad/range' id:1206 op device:{requested: '', assigned: ''} def:{{{node gradients_49/MaxNeuronSelection_3/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_3/Max"], _has_manual_control_dependencies=true](gradients_49/MaxNeuronSelection_3/Max_grad/range/start, gradients_49/MaxNeuronSelection_3/Max_grad/Size, gradients_49/MaxNeuronSelection_3/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:05.836379: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_49/MaxNeuronSelection_3/Max_grad/mod' id:1202 op device:{requested: '', assigned: ''} def:{{{node gradients_49/MaxNeuronSelection_3/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_3/Max"], _has_manual_control_dependencies=true](gradients_49/MaxNeuronSelection_3/Max_grad/add, gradients_49/MaxNeuronSelection_3/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:05.974968: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_49/MaxNeuronSelection_3/Max_grad/ones' id:1208 op device:{requested: '', assigned: ''} def:{{{node gradients_49/MaxNeuronSelection_3/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_3/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_49/MaxNeuronSelection_3/Max_grad/Shape_1, gradients_49/MaxNeuronSelection_3/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:06.121150: W tensorflow/c/c_api.cc:291] Operation '{name:'MaxNeuronSelection_3/Max/reduction_indices' id:1120 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_3/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:06.270404: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_12/x' id:1226 op device:{requested: '', assigned: ''} def:{{{node mul_12/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:06.414596: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_4' id:1223 op device:{requested: '', assigned: ''} def:{{{node Const_4}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:06.767461: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:06.895756: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_13/x' id:1268 op device:{requested: '', assigned: ''} def:{{{node mul_13/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:07.014713: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_5' id:1265 op device:{requested: '', assigned: ''} def:{{{node Const_5}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:07.423605: W tensorflow/c/c_api.cc:291] Operation '{name:'reversed_kernel_conv2d_1/Conv2D/ReadVariableOp' id:1296 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:07.579057: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:07.776707: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_14/x' id:1303 op device:{requested: '', assigned: ''} def:{{{node mul_14/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:07.909958: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_6' id:1300 op device:{requested: '', assigned: ''} def:{{{node Const_6}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:08.286791: W tensorflow/c/c_api.cc:291] Operation '{name:'reversed_kernel_conv2d/Conv2D/ReadVariableOp' id:1330 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:08.421410: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:08.563573: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_15/x' id:1337 op device:{requested: '', assigned: ''} def:{{{node mul_15/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:08.695630: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_7' id:1334 op device:{requested: '', assigned: ''} def:{{{node Const_7}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:09.321705: W tensorflow/c/c_api.cc:291] Operation '{name:'kernel_14/Assign' id:1387 op device:{requested: '', assigned: ''} def:{{{node kernel_14/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_14, kernel_14/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# ...
# 2023-02-28 12:31:10.843012: W tensorflow/c/c_api.cc:291] Operation '{name:'reversed_kernel_conv2d_1_1/Conv2D/ReadVariableOp' id:1534 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_1_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:11.010500: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:11.573402: W tensorflow/c/c_api.cc:291] Operation '{name:'reversed_kernel_conv2d_2/Conv2D/ReadVariableOp' id:1570 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_2/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:11.766421: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:12.612558: W tensorflow/c/c_api.cc:291] Operation '{name:'kernel_21/Assign' id:1758 op device:{requested: '', assigned: ''} def:{{{node kernel_21/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_21, kernel_21/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:12.858680: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_71/MaxNeuronSelection_5/Max_grad/range' id:1854 op device:{requested: '', assigned: ''} def:{{{node gradients_71/MaxNeuronSelection_5/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_5/Max"], _has_manual_control_dependencies=true](gradients_71/MaxNeuronSelection_5/Max_grad/range/start, gradients_71/MaxNeuronSelection_5/Max_grad/Size, gradients_71/MaxNeuronSelection_5/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:13.015006: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_71/MaxNeuronSelection_5/Max_grad/mod' id:1850 op device:{requested: '', assigned: ''} def:{{{node gradients_71/MaxNeuronSelection_5/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_5/Max"], _has_manual_control_dependencies=true](gradients_71/MaxNeuronSelection_5/Max_grad/add, gradients_71/MaxNeuronSelection_5/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:13.174474: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_71/MaxNeuronSelection_5/Max_grad/ones' id:1856 op device:{requested: '', assigned: ''} def:{{{node gradients_71/MaxNeuronSelection_5/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_5/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_71/MaxNeuronSelection_5/Max_grad/Shape_1, gradients_71/MaxNeuronSelection_5/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:13.335575: W tensorflow/c/c_api.cc:291] Operation '{name:'MaxNeuronSelection_5/Max/reduction_indices' id:1596 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_5/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:13.497680: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_32/x' id:1883 op device:{requested: '', assigned: ''} def:{{{node mul_32/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:13.656420: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_8' id:1880 op device:{requested: '', assigned: ''} def:{{{node Const_8}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:13.825903: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_30' id:1801 op device:{requested: '', assigned: ''} def:{{{node mul_30}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_56, Cast_30)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:14.119595: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_24' id:1727 op device:{requested: '', assigned: ''} def:{{{node mul_24}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_44, Cast_24)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:14.322782: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:14.534390: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_33/x' id:1949 op device:{requested: '', assigned: ''} def:{{{node mul_33/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:14.737716: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_9' id:1946 op device:{requested: '', assigned: ''} def:{{{node Const_9}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:14.935017: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_26' id:1739 op device:{requested: '', assigned: ''} def:{{{node mul_26}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_48, Cast_26)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:15.213157: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_20' id:1665 op device:{requested: '', assigned: ''} def:{{{node mul_20}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_36, Cast_20)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:15.380016: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_20' id:1665 op device:{requested: '', assigned: ''} def:{{{node mul_20}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_36, Cast_20)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:15.550486: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:15.722541: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_34/x' id:2000 op device:{requested: '', assigned: ''} def:{{{node mul_34/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:15.887408: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_10' id:1997 op device:{requested: '', assigned: ''} def:{{{node Const_10}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:16.058700: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_22' id:1677 op device:{requested: '', assigned: ''} def:{{{node mul_22}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_40, Cast_22)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:16.227234: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_22' id:1677 op device:{requested: '', assigned: ''} def:{{{node mul_22}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_40, Cast_22)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:16.506296: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_16' id:1603 op device:{requested: '', assigned: ''} def:{{{node mul_16}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_28, Cast_16)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:16.679472: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_16' id:1603 op device:{requested: '', assigned: ''} def:{{{node mul_16}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_28, Cast_16)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:16.859237: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:17.040653: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_35/x' id:2052 op device:{requested: '', assigned: ''} def:{{{node mul_35/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:17.212755: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_11' id:2049 op device:{requested: '', assigned: ''} def:{{{node Const_11}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:17.390482: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_18' id:1615 op device:{requested: '', assigned: ''} def:{{{node mul_18}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_32, Cast_18)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:31:17.563988: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_18' id:1615 op device:{requested: '', assigned: ''} def:{{{node mul_18}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_32, Cast_18)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
# Plot
plt.rcParams['figure.figsize'] = [10, 10]
fig, ax = plt.subplots(1,8)
fig.subplots_adjust(hspace=0, wspace=0)

ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)
ax[0].spines['bottom'].set_visible(False)
ax[0].spines['left'].set_visible(False)      
ax[0].imshow(x_train_nom[sample_no])
ax[0].set_xticklabels([])
ax[0].set_yticklabels([])
ax[0].tick_params(left=False)
ax[0].tick_params(bottom=False)
#ax[0].axis('off')
ax[0].set_xlabel('sample', fontsize=7)

ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)
ax[1].spines['bottom'].set_visible(False)
ax[1].spines['left'].set_visible(False) 
# ax[1].imshow(a1[0], cmap="seismic")
ax[1].imshow(a1g[0], cmap="seismic", clim=(-1, 1))
# ax[1].imshow(x_train_nom[sample_no])
ax[1].set_xticklabels([])
ax[1].set_yticklabels([])
ax[1].tick_params(left=False)
ax[1].tick_params(bottom=False)
#ax[1].axis('off')
ax[1].set_xlabel('gradient', fontsize=7)

ax[2].spines['top'].set_visible(False)
ax[2].spines['right'].set_visible(False)
ax[2].spines['bottom'].set_visible(False)
ax[2].spines['left'].set_visible(False) 
ax[2].imshow(a1itg[0], cmap="seismic", clim=(-1, 1))
ax[2].set_xticklabels([])
ax[2].set_yticklabels([])
ax[2].tick_params(left=False)
ax[2].tick_params(bottom=False)
#ax[2].axis('off')
ax[2].set_xlabel('input*gradient', fontsize=7)

ax[3].spines['top'].set_visible(False)
ax[3].spines['right'].set_visible(False)
ax[3].spines['bottom'].set_visible(False)
ax[3].spines['left'].set_visible(False) 
ax[3].imshow(a1dt[0], cmap="seismic", clim=(-1, 1))
ax[3].set_xticklabels([])
ax[3].set_yticklabels([])
ax[3].tick_params(left=False)
ax[3].tick_params(bottom=False)
#ax[3].axis('off')
ax[3].set_xlabel('Deep Taylor', fontsize=7)

ax[4].spines['top'].set_visible(False)
ax[4].spines['right'].set_visible(False)
ax[4].spines['bottom'].set_visible(False)
ax[4].spines['left'].set_visible(False) 
ax[4].imshow(a1ig[0], cmap="seismic", clim=(-1, 1))
ax[4].set_xticklabels([])
ax[4].set_yticklabels([])
ax[4].tick_params(left=False)
ax[4].tick_params(bottom=False)
#ax[4].axis('off')
ax[4].set_xlabel('integrated gradients', fontsize=7)

ax[5].spines['top'].set_visible(False)
ax[5].spines['right'].set_visible(False)
ax[5].spines['bottom'].set_visible(False)
ax[5].spines['left'].set_visible(False) 
ax[5].imshow(a1lrpz[0], cmap="seismic", clim=(-1, 1))
ax[5].set_xticklabels([])
ax[5].set_yticklabels([])
ax[5].tick_params(left=False)
ax[5].tick_params(bottom=False)
#ax[5].axis('off')
ax[5].set_xlabel('LRP-z', fontsize=7)

ax[6].spines['top'].set_visible(False)
ax[6].spines['right'].set_visible(False)
ax[6].spines['bottom'].set_visible(False)
ax[6].spines['left'].set_visible(False)
ax[6].imshow(a1lrpe[0], cmap="seismic", clim=(-1, 1))
ax[6].set_xticklabels([])
ax[6].set_yticklabels([])
ax[6].tick_params(left=False)
ax[6].tick_params(bottom=False)
#ax[6].axis('off')
ax[6].set_xlabel('LRP-epsilon', fontsize=7)

ax[7].spines['top'].set_visible(False)
ax[7].spines['right'].set_visible(False)
ax[7].spines['bottom'].set_visible(False)
ax[7].spines['left'].set_visible(False)
ax[7].imshow(a1lrpa1b0[0], cmap="seismic", clim=(-1, 1))
ax[7].set_xticklabels([])
ax[7].set_yticklabels([])
ax[7].tick_params(left=False)
ax[7].tick_params(bottom=False)
#ax[7].axis('off')
ax[7].set_xlabel('LRP-alpha1-beta0', fontsize=7)
# Out:
# Text(0.5, 0, 'LRP-alpha1-beta0')

# %%
keras.backend.clear_session()

inputs = Input(shape=(32,32,3))
conv2d1 = Conv2D(filters=32,kernel_size=(3,3),input_shape=(32,32,3),activation='relu', kernel_regularizer=l2(0.001))
conv2d2 = Conv2D(filters=32,kernel_size=(3,3),activation='relu', kernel_regularizer=l2(0.001))
maxpool2d = MaxPooling2D(pool_size=(2,2))
dropout = Dropout(0.2)
conv2d3 = Conv2D(filters=64,kernel_size=(3,3),activation='relu', kernel_regularizer=l2(0.001))
conv2d4 = Conv2D(filters=64,kernel_size=(3,3),activation='relu', kernel_regularizer=l2(0.001))
maxpool2d = MaxPooling2D(pool_size=(2,2))
conv2d3 = Conv2D(filters=128,kernel_size=(3,3),activation='relu', kernel_regularizer=l2(0.001))
conv2d4 = Conv2D(filters=128,kernel_size=(3,3),activation='relu', kernel_regularizer=l2(0.001))
maxpool2d = MaxPooling2D(pool_size=(2,2))
flatten = Flatten()
dense1 = Dense(128, activation='relu', kernel_regularizer=l2(0.001))
dense2 = Dense(10, activation='softmax')

x = conv2d1(inputs)
x = maxpool2d(x)
x = dropout(x)
x = conv2d2(x)
x = maxpool2d(x)
x = dropout(x)
x = flatten(x)
x = dense1(x)
x = dropout(x)
x = dense2(x)

model2 = keras.Model(inputs=inputs, outputs=x) 

mod_h5_2 = 'CIFAR10_model_2.h5'

checkpoint = ModelCheckpoint(mod_h5_2, monitor='val_loss',
                             verbose=1,save_best_only=True)
        
callbacks = [checkpoint]
model2.compile(optimizer='adam',
            loss='categorical_crossentropy', metrics=['acc'])
fit2 = model2.fit(x_train_nom, y_train_onehot,
            batch_size=1000,
            epochs=100, 
            shuffle=True,
            validation_split = 0.1, 
            callbacks=callbacks)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
# 2023-02-28 12:31:19.918381: W tensorflow/c/c_api.cc:291] Operation '{name:'training/Adam/learning_rate/Assign' id:365 op device:{requested: '', assigned: ''} def:{{{node training/Adam/learning_rate/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/learning_rate, training/Adam/learning_rate/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 45000/45000 [==============================] - ETA: 0s - loss: 2.2600 - acc: 0.2320
# 2023-02-28 12:31:26.436421: W tensorflow/c/c_api.cc:291] Operation '{name:'loss/AddN_1' id:233 op device:{requested: '', assigned: ''} def:{{{node loss/AddN_1}} = AddN[N=2, T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul, loss/AddN)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 1.98332, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 154us/sample - loss: 2.2600 - acc: 0.2320 - val_loss: 1.9833 - val_acc: 0.3552
# Epoch 2/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.8679 - acc: 0.3713
# Epoch 2: val_loss improved from 1.98332 to 1.73911, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.8679 - acc: 0.3713 - val_loss: 1.7391 - val_acc: 0.4226
# Epoch 3/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.7163 - acc: 0.4240
# Epoch 3: val_loss improved from 1.73911 to 1.62514, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 155us/sample - loss: 1.7163 - acc: 0.4240 - val_loss: 1.6251 - val_acc: 0.4594
# Epoch 4/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.6310 - acc: 0.4544
# Epoch 4: val_loss improved from 1.62514 to 1.55547, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.6310 - acc: 0.4544 - val_loss: 1.5555 - val_acc: 0.4942
# Epoch 5/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.5674 - acc: 0.4731
# Epoch 5: val_loss improved from 1.55547 to 1.50062, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.5674 - acc: 0.4731 - val_loss: 1.5006 - val_acc: 0.5070
# Epoch 6/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.5204 - acc: 0.4914
# Epoch 6: val_loss improved from 1.50062 to 1.44908, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.5204 - acc: 0.4914 - val_loss: 1.4491 - val_acc: 0.5316
# Epoch 7/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.4733 - acc: 0.5126
# Epoch 7: val_loss improved from 1.44908 to 1.42318, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 156us/sample - loss: 1.4733 - acc: 0.5126 - val_loss: 1.4232 - val_acc: 0.5360
# Epoch 8/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.4437 - acc: 0.5190
# Epoch 8: val_loss improved from 1.42318 to 1.36046, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.4437 - acc: 0.5190 - val_loss: 1.3605 - val_acc: 0.5666
# Epoch 9/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.4197 - acc: 0.5309
# Epoch 9: val_loss improved from 1.36046 to 1.34770, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 154us/sample - loss: 1.4197 - acc: 0.5309 - val_loss: 1.3477 - val_acc: 0.5706
# Epoch 10/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.3914 - acc: 0.5406
# Epoch 10: val_loss improved from 1.34770 to 1.32122, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 154us/sample - loss: 1.3914 - acc: 0.5406 - val_loss: 1.3212 - val_acc: 0.5736
# Epoch 11/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.3769 - acc: 0.5483
# Epoch 11: val_loss improved from 1.32122 to 1.30153, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 148us/sample - loss: 1.3769 - acc: 0.5483 - val_loss: 1.3015 - val_acc: 0.5834
# Epoch 12/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.3586 - acc: 0.5555
# Epoch 12: val_loss improved from 1.30153 to 1.27809, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.3586 - acc: 0.5555 - val_loss: 1.2781 - val_acc: 0.5968
# Epoch 13/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.3360 - acc: 0.5647
# Epoch 13: val_loss improved from 1.27809 to 1.26540, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 156us/sample - loss: 1.3360 - acc: 0.5647 - val_loss: 1.2654 - val_acc: 0.6040
# Epoch 14/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.3230 - acc: 0.5719
# Epoch 14: val_loss improved from 1.26540 to 1.24793, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.3230 - acc: 0.5719 - val_loss: 1.2479 - val_acc: 0.6100
# Epoch 15/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.3073 - acc: 0.5777
# Epoch 15: val_loss improved from 1.24793 to 1.22922, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.3073 - acc: 0.5777 - val_loss: 1.2292 - val_acc: 0.6238
# Epoch 16/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2866 - acc: 0.5863
# Epoch 16: val_loss improved from 1.22922 to 1.22639, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.2866 - acc: 0.5863 - val_loss: 1.2264 - val_acc: 0.6196
# Epoch 17/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2778 - acc: 0.5906
# Epoch 17: val_loss improved from 1.22639 to 1.20056, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.2778 - acc: 0.5906 - val_loss: 1.2006 - val_acc: 0.6284
# Epoch 18/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2648 - acc: 0.5961
# Epoch 18: val_loss did not improve from 1.20056
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.2648 - acc: 0.5961 - val_loss: 1.2013 - val_acc: 0.6288
# Epoch 19/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2541 - acc: 0.5986
# Epoch 19: val_loss improved from 1.20056 to 1.18357, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.2541 - acc: 0.5986 - val_loss: 1.1836 - val_acc: 0.6348
# Epoch 20/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2383 - acc: 0.6040
# Epoch 20: val_loss improved from 1.18357 to 1.17327, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.2383 - acc: 0.6040 - val_loss: 1.1733 - val_acc: 0.6392
# Epoch 21/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2369 - acc: 0.6058
# Epoch 21: val_loss improved from 1.17327 to 1.16192, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.2369 - acc: 0.6058 - val_loss: 1.1619 - val_acc: 0.6482
# Epoch 22/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2216 - acc: 0.6132
# Epoch 22: val_loss improved from 1.16192 to 1.14949, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 155us/sample - loss: 1.2216 - acc: 0.6132 - val_loss: 1.1495 - val_acc: 0.6510
# Epoch 23/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2128 - acc: 0.6189
# Epoch 23: val_loss improved from 1.14949 to 1.14436, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.2128 - acc: 0.6189 - val_loss: 1.1444 - val_acc: 0.6540
# Epoch 24/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.2013 - acc: 0.6230
# Epoch 24: val_loss improved from 1.14436 to 1.12486, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.2013 - acc: 0.6230 - val_loss: 1.1249 - val_acc: 0.6630
# Epoch 25/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1937 - acc: 0.6270
# Epoch 25: val_loss did not improve from 1.12486
# 45000/45000 [==============================] - 7s 150us/sample - loss: 1.1937 - acc: 0.6270 - val_loss: 1.1366 - val_acc: 0.6552
# Epoch 26/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1813 - acc: 0.6312
# Epoch 26: val_loss improved from 1.12486 to 1.11786, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.1813 - acc: 0.6312 - val_loss: 1.1179 - val_acc: 0.6604
# Epoch 27/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1757 - acc: 0.6339
# Epoch 27: val_loss did not improve from 1.11786
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.1757 - acc: 0.6339 - val_loss: 1.1211 - val_acc: 0.6604
# Epoch 28/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1606 - acc: 0.6377
# Epoch 28: val_loss improved from 1.11786 to 1.10250, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.1606 - acc: 0.6377 - val_loss: 1.1025 - val_acc: 0.6728
# Epoch 29/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1579 - acc: 0.6363
# Epoch 29: val_loss did not improve from 1.10250
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.1579 - acc: 0.6363 - val_loss: 1.1025 - val_acc: 0.6758
# Epoch 30/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1478 - acc: 0.6441
# Epoch 30: val_loss improved from 1.10250 to 1.09797, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.1478 - acc: 0.6441 - val_loss: 1.0980 - val_acc: 0.6742
# Epoch 31/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1449 - acc: 0.6474
# Epoch 31: val_loss improved from 1.09797 to 1.09686, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.1449 - acc: 0.6474 - val_loss: 1.0969 - val_acc: 0.6716
# Epoch 32/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1421 - acc: 0.6462
# Epoch 32: val_loss improved from 1.09686 to 1.08854, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 149us/sample - loss: 1.1421 - acc: 0.6462 - val_loss: 1.0885 - val_acc: 0.6700
# Epoch 33/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1358 - acc: 0.6488
# Epoch 33: val_loss improved from 1.08854 to 1.07597, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.1358 - acc: 0.6488 - val_loss: 1.0760 - val_acc: 0.6824
# Epoch 34/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1228 - acc: 0.6559
# Epoch 34: val_loss improved from 1.07597 to 1.07211, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.1228 - acc: 0.6559 - val_loss: 1.0721 - val_acc: 0.6828
# Epoch 35/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1171 - acc: 0.6590
# Epoch 35: val_loss improved from 1.07211 to 1.07132, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.1171 - acc: 0.6590 - val_loss: 1.0713 - val_acc: 0.6820
# Epoch 36/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1106 - acc: 0.6593
# Epoch 36: val_loss improved from 1.07132 to 1.05160, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 149us/sample - loss: 1.1106 - acc: 0.6593 - val_loss: 1.0516 - val_acc: 0.6848
# Epoch 37/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.1024 - acc: 0.6647
# Epoch 37: val_loss did not improve from 1.05160
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.1024 - acc: 0.6647 - val_loss: 1.0519 - val_acc: 0.6880
# Epoch 38/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0969 - acc: 0.6675
# Epoch 38: val_loss did not improve from 1.05160
# 45000/45000 [==============================] - 7s 149us/sample - loss: 1.0969 - acc: 0.6675 - val_loss: 1.0560 - val_acc: 0.6872
# Epoch 39/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0975 - acc: 0.6647
# Epoch 39: val_loss improved from 1.05160 to 1.04938, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.0975 - acc: 0.6647 - val_loss: 1.0494 - val_acc: 0.6946
# Epoch 40/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0894 - acc: 0.6682
# Epoch 40: val_loss improved from 1.04938 to 1.03730, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 156us/sample - loss: 1.0894 - acc: 0.6682 - val_loss: 1.0373 - val_acc: 0.6942
# Epoch 41/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0795 - acc: 0.6752
# Epoch 41: val_loss improved from 1.03730 to 1.03453, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.0795 - acc: 0.6752 - val_loss: 1.0345 - val_acc: 0.6968
# Epoch 42/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0730 - acc: 0.6742
# Epoch 42: val_loss improved from 1.03453 to 1.02295, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.0730 - acc: 0.6742 - val_loss: 1.0230 - val_acc: 0.6966
# Epoch 43/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0769 - acc: 0.6760
# Epoch 43: val_loss did not improve from 1.02295
# 45000/45000 [==============================] - 7s 150us/sample - loss: 1.0769 - acc: 0.6760 - val_loss: 1.0371 - val_acc: 0.6938
# Epoch 44/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0668 - acc: 0.6772
# Epoch 44: val_loss improved from 1.02295 to 1.01500, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.0668 - acc: 0.6772 - val_loss: 1.0150 - val_acc: 0.7030
# Epoch 45/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0658 - acc: 0.6788
# Epoch 45: val_loss did not improve from 1.01500
# 45000/45000 [==============================] - 7s 148us/sample - loss: 1.0658 - acc: 0.6788 - val_loss: 1.0213 - val_acc: 0.6978
# Epoch 46/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0525 - acc: 0.6839
# Epoch 46: val_loss did not improve from 1.01500
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.0525 - acc: 0.6839 - val_loss: 1.0179 - val_acc: 0.7022
# Epoch 47/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0604 - acc: 0.6806
# Epoch 47: val_loss did not improve from 1.01500
# 45000/45000 [==============================] - 7s 150us/sample - loss: 1.0604 - acc: 0.6806 - val_loss: 1.0206 - val_acc: 0.6976
# Epoch 48/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0469 - acc: 0.6874
# Epoch 48: val_loss improved from 1.01500 to 1.01196, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 156us/sample - loss: 1.0469 - acc: 0.6874 - val_loss: 1.0120 - val_acc: 0.6982
# Epoch 49/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0462 - acc: 0.6852
# Epoch 49: val_loss did not improve from 1.01196
# 45000/45000 [==============================] - 7s 150us/sample - loss: 1.0462 - acc: 0.6852 - val_loss: 1.0160 - val_acc: 0.7016
# Epoch 50/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0439 - acc: 0.6864
# Epoch 50: val_loss did not improve from 1.01196
# 45000/45000 [==============================] - 7s 153us/sample - loss: 1.0439 - acc: 0.6864 - val_loss: 1.0151 - val_acc: 0.7042
# Epoch 51/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0293 - acc: 0.6935
# Epoch 51: val_loss improved from 1.01196 to 1.00688, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.0293 - acc: 0.6935 - val_loss: 1.0069 - val_acc: 0.7050
# Epoch 52/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0265 - acc: 0.6937
# Epoch 52: val_loss improved from 1.00688 to 0.99961, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.0265 - acc: 0.6937 - val_loss: 0.9996 - val_acc: 0.7096
# Epoch 53/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0215 - acc: 0.6969
# Epoch 53: val_loss improved from 0.99961 to 0.99513, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 1.0215 - acc: 0.6969 - val_loss: 0.9951 - val_acc: 0.7138
# Epoch 54/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0252 - acc: 0.6954
# Epoch 54: val_loss did not improve from 0.99513
# 45000/45000 [==============================] - 7s 146us/sample - loss: 1.0252 - acc: 0.6954 - val_loss: 1.0079 - val_acc: 0.7086
# Epoch 55/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0184 - acc: 0.6977
# Epoch 55: val_loss did not improve from 0.99513
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.0184 - acc: 0.6977 - val_loss: 0.9986 - val_acc: 0.7088
# Epoch 56/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0170 - acc: 0.6979
# Epoch 56: val_loss improved from 0.99513 to 0.98762, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.0170 - acc: 0.6979 - val_loss: 0.9876 - val_acc: 0.7132
# Epoch 57/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0079 - acc: 0.7025
# Epoch 57: val_loss improved from 0.98762 to 0.98459, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 155us/sample - loss: 1.0079 - acc: 0.7025 - val_loss: 0.9846 - val_acc: 0.7128
# Epoch 58/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0028 - acc: 0.7039
# Epoch 58: val_loss did not improve from 0.98459
# 45000/45000 [==============================] - 7s 151us/sample - loss: 1.0028 - acc: 0.7039 - val_loss: 0.9852 - val_acc: 0.7132
# Epoch 59/100
# 45000/45000 [==============================] - ETA: 0s - loss: 1.0043 - acc: 0.7030
# Epoch 59: val_loss did not improve from 0.98459
# 45000/45000 [==============================] - 7s 149us/sample - loss: 1.0043 - acc: 0.7030 - val_loss: 0.9858 - val_acc: 0.7180
# Epoch 60/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9994 - acc: 0.7031
# Epoch 60: val_loss did not improve from 0.98459
# 45000/45000 [==============================] - 7s 151us/sample - loss: 0.9994 - acc: 0.7031 - val_loss: 0.9850 - val_acc: 0.7184
# Epoch 61/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9942 - acc: 0.7073
# Epoch 61: val_loss improved from 0.98459 to 0.97545, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 0.9942 - acc: 0.7073 - val_loss: 0.9755 - val_acc: 0.7188
# Epoch 62/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9910 - acc: 0.7073
# Epoch 62: val_loss improved from 0.97545 to 0.97369, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 154us/sample - loss: 0.9910 - acc: 0.7073 - val_loss: 0.9737 - val_acc: 0.7182
# Epoch 63/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9888 - acc: 0.7073
# Epoch 63: val_loss did not improve from 0.97369
# 45000/45000 [==============================] - 7s 149us/sample - loss: 0.9888 - acc: 0.7073 - val_loss: 0.9824 - val_acc: 0.7170
# Epoch 64/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9865 - acc: 0.7112
# Epoch 64: val_loss did not improve from 0.97369
# 45000/45000 [==============================] - 7s 150us/sample - loss: 0.9865 - acc: 0.7112 - val_loss: 0.9779 - val_acc: 0.7186
# Epoch 65/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9799 - acc: 0.7122
# Epoch 65: val_loss did not improve from 0.97369
# 45000/45000 [==============================] - 7s 147us/sample - loss: 0.9799 - acc: 0.7122 - val_loss: 0.9815 - val_acc: 0.7248
# Epoch 66/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9820 - acc: 0.7116
# Epoch 66: val_loss improved from 0.97369 to 0.97289, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 162us/sample - loss: 0.9820 - acc: 0.7116 - val_loss: 0.9729 - val_acc: 0.7224
# Epoch 67/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9700 - acc: 0.7143
# Epoch 67: val_loss improved from 0.97289 to 0.96991, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 163us/sample - loss: 0.9700 - acc: 0.7143 - val_loss: 0.9699 - val_acc: 0.7234
# Epoch 68/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9729 - acc: 0.7152
# Epoch 68: val_loss did not improve from 0.96991
# 45000/45000 [==============================] - 7s 152us/sample - loss: 0.9729 - acc: 0.7152 - val_loss: 0.9748 - val_acc: 0.7234
# Epoch 69/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9704 - acc: 0.7162
# Epoch 69: val_loss did not improve from 0.96991
# 45000/45000 [==============================] - 7s 150us/sample - loss: 0.9704 - acc: 0.7162 - val_loss: 0.9707 - val_acc: 0.7228
# Epoch 70/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9625 - acc: 0.7205
# Epoch 70: val_loss improved from 0.96991 to 0.96907, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 0.9625 - acc: 0.7205 - val_loss: 0.9691 - val_acc: 0.7254
# Epoch 71/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9679 - acc: 0.7180
# Epoch 71: val_loss improved from 0.96907 to 0.96486, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 151us/sample - loss: 0.9679 - acc: 0.7180 - val_loss: 0.9649 - val_acc: 0.7246
# Epoch 72/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9631 - acc: 0.7198
# Epoch 72: val_loss improved from 0.96486 to 0.95923, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 149us/sample - loss: 0.9631 - acc: 0.7198 - val_loss: 0.9592 - val_acc: 0.7266
# Epoch 73/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9612 - acc: 0.7191
# Epoch 73: val_loss improved from 0.95923 to 0.95370, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 155us/sample - loss: 0.9612 - acc: 0.7191 - val_loss: 0.9537 - val_acc: 0.7262
# Epoch 74/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9542 - acc: 0.7224
# Epoch 74: val_loss did not improve from 0.95370
# 45000/45000 [==============================] - 7s 151us/sample - loss: 0.9542 - acc: 0.7224 - val_loss: 0.9599 - val_acc: 0.7258
# Epoch 75/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9495 - acc: 0.7240
# Epoch 75: val_loss did not improve from 0.95370
# 45000/45000 [==============================] - 7s 151us/sample - loss: 0.9495 - acc: 0.7240 - val_loss: 0.9643 - val_acc: 0.7282
# Epoch 76/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9549 - acc: 0.7216
# Epoch 76: val_loss did not improve from 0.95370
# 45000/45000 [==============================] - 7s 151us/sample - loss: 0.9549 - acc: 0.7216 - val_loss: 0.9596 - val_acc: 0.7322
# Epoch 77/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9458 - acc: 0.7248
# Epoch 77: val_loss did not improve from 0.95370
# 45000/45000 [==============================] - 7s 147us/sample - loss: 0.9458 - acc: 0.7248 - val_loss: 0.9566 - val_acc: 0.7292
# Epoch 78/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9434 - acc: 0.7260
# Epoch 78: val_loss did not improve from 0.95370
# 45000/45000 [==============================] - 7s 150us/sample - loss: 0.9434 - acc: 0.7260 - val_loss: 0.9544 - val_acc: 0.7322
# Epoch 79/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9400 - acc: 0.7262
# Epoch 79: val_loss did not improve from 0.95370
# 45000/45000 [==============================] - 7s 154us/sample - loss: 0.9400 - acc: 0.7262 - val_loss: 0.9542 - val_acc: 0.7314
# Epoch 80/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9410 - acc: 0.7270
# Epoch 80: val_loss improved from 0.95370 to 0.94944, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 0.9410 - acc: 0.7270 - val_loss: 0.9494 - val_acc: 0.7386
# Epoch 81/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9372 - acc: 0.7288
# Epoch 81: val_loss did not improve from 0.94944
# 45000/45000 [==============================] - 7s 147us/sample - loss: 0.9372 - acc: 0.7288 - val_loss: 0.9514 - val_acc: 0.7300
# Epoch 82/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9340 - acc: 0.7286
# Epoch 82: val_loss did not improve from 0.94944
# 45000/45000 [==============================] - 7s 148us/sample - loss: 0.9340 - acc: 0.7286 - val_loss: 0.9536 - val_acc: 0.7292
# Epoch 83/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9318 - acc: 0.7300
# Epoch 83: val_loss improved from 0.94944 to 0.94711, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 154us/sample - loss: 0.9318 - acc: 0.7300 - val_loss: 0.9471 - val_acc: 0.7308
# Epoch 84/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9296 - acc: 0.7333
# Epoch 84: val_loss improved from 0.94711 to 0.94572, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 152us/sample - loss: 0.9296 - acc: 0.7333 - val_loss: 0.9457 - val_acc: 0.7308
# Epoch 85/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9234 - acc: 0.7342
# Epoch 85: val_loss did not improve from 0.94572
# 45000/45000 [==============================] - 7s 149us/sample - loss: 0.9234 - acc: 0.7342 - val_loss: 0.9635 - val_acc: 0.7268
# Epoch 86/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9330 - acc: 0.7291
# Epoch 86: val_loss did not improve from 0.94572
# 45000/45000 [==============================] - 7s 147us/sample - loss: 0.9330 - acc: 0.7291 - val_loss: 0.9532 - val_acc: 0.7250
# Epoch 87/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9230 - acc: 0.7328
# Epoch 87: val_loss did not improve from 0.94572
# 45000/45000 [==============================] - 7s 150us/sample - loss: 0.9230 - acc: 0.7328 - val_loss: 0.9470 - val_acc: 0.7342
# Epoch 88/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9227 - acc: 0.7368
# Epoch 88: val_loss did not improve from 0.94572
# 45000/45000 [==============================] - 7s 150us/sample - loss: 0.9227 - acc: 0.7368 - val_loss: 0.9500 - val_acc: 0.7266
# Epoch 89/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9173 - acc: 0.7356
# Epoch 89: val_loss improved from 0.94572 to 0.93784, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 155us/sample - loss: 0.9173 - acc: 0.7356 - val_loss: 0.9378 - val_acc: 0.7366
# Epoch 90/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9189 - acc: 0.7368
# Epoch 90: val_loss did not improve from 0.93784
# 45000/45000 [==============================] - 7s 151us/sample - loss: 0.9189 - acc: 0.7368 - val_loss: 0.9403 - val_acc: 0.7332
# Epoch 91/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9206 - acc: 0.7357
# Epoch 91: val_loss improved from 0.93784 to 0.93589, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 154us/sample - loss: 0.9206 - acc: 0.7357 - val_loss: 0.9359 - val_acc: 0.7410
# Epoch 92/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9159 - acc: 0.7374
# Epoch 92: val_loss did not improve from 0.93589
# 45000/45000 [==============================] - 7s 151us/sample - loss: 0.9159 - acc: 0.7374 - val_loss: 0.9498 - val_acc: 0.7292
# Epoch 93/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9169 - acc: 0.7361
# Epoch 93: val_loss did not improve from 0.93589
# 45000/45000 [==============================] - 7s 154us/sample - loss: 0.9169 - acc: 0.7361 - val_loss: 0.9477 - val_acc: 0.7314
# Epoch 94/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9094 - acc: 0.7392
# Epoch 94: val_loss did not improve from 0.93589
# 45000/45000 [==============================] - 7s 151us/sample - loss: 0.9094 - acc: 0.7392 - val_loss: 0.9361 - val_acc: 0.7400
# Epoch 95/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9057 - acc: 0.7413
# Epoch 95: val_loss improved from 0.93589 to 0.93484, saving model to CIFAR10_model_2.h5
# 45000/45000 [==============================] - 7s 150us/sample - loss: 0.9057 - acc: 0.7413 - val_loss: 0.9348 - val_acc: 0.7400
# Epoch 96/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9054 - acc: 0.7415
# Epoch 96: val_loss did not improve from 0.93484
# 45000/45000 [==============================] - 7s 153us/sample - loss: 0.9054 - acc: 0.7415 - val_loss: 0.9433 - val_acc: 0.7354
# Epoch 97/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.9050 - acc: 0.7414
# Epoch 97: val_loss did not improve from 0.93484
# 45000/45000 [==============================] - 7s 152us/sample - loss: 0.9050 - acc: 0.7414 - val_loss: 0.9358 - val_acc: 0.7386
# Epoch 98/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8979 - acc: 0.7430
# Epoch 98: val_loss did not improve from 0.93484
# 45000/45000 [==============================] - 7s 150us/sample - loss: 0.8979 - acc: 0.7430 - val_loss: 0.9491 - val_acc: 0.7318
# Epoch 99/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8974 - acc: 0.7427
# Epoch 99: val_loss did not improve from 0.93484
# 45000/45000 [==============================] - 7s 151us/sample - loss: 0.8974 - acc: 0.7427 - val_loss: 0.9368 - val_acc: 0.7416
# Epoch 100/100
# 45000/45000 [==============================] - ETA: 0s - loss: 0.8953 - acc: 0.7461
# Epoch 100: val_loss did not improve from 0.93484
# 45000/45000 [==============================] - 7s 152us/sample - loss: 0.8953 - acc: 0.7461 - val_loss: 0.9388 - val_acc: 0.7418

# %%
keras.backend.clear_session()

inputs = Input(shape=(32,32,3))
conv2d1 = Conv2D(filters=32,kernel_size=(3,3),input_shape=(32,32,3),activation='relu', kernel_regularizer=l2(0.001))
conv2d2 = Conv2D(filters=32,kernel_size=(3,3),activation='relu', kernel_regularizer=l2(0.001))
maxpool2d = MaxPooling2D(pool_size=(2,2))
dropout = Dropout(0.2)
conv2d3 = Conv2D(filters=64,kernel_size=(3,3),activation='relu', kernel_regularizer=l2(0.001))
conv2d4 = Conv2D(filters=64,kernel_size=(3,3),activation='relu', kernel_regularizer=l2(0.001))
maxpool2d = MaxPooling2D(pool_size=(2,2))
conv2d3 = Conv2D(filters=128,kernel_size=(3,3),activation='relu', kernel_regularizer=l2(0.001))
conv2d4 = Conv2D(filters=128,kernel_size=(3,3),activation='relu', kernel_regularizer=l2(0.001))
maxpool2d = MaxPooling2D(pool_size=(2,2))
flatten = Flatten()
dense1 = Dense(128, activation='relu', kernel_regularizer=l2(0.001))
dense2 = Dense(10, activation='softmax')

x = conv2d1(inputs)
x = maxpool2d(x)
x = dropout(x)
x = conv2d2(x)
x = maxpool2d(x)
x = dropout(x)
x = flatten(x)
x = dense1(x)
x = dropout(x)
x = dense2(x)

best_model2 = keras.Model(inputs=inputs, outputs=x) 
best_model2.load_weights(mod_h5_2)
best_model2.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['acc'])

y_test_pred2 = best_model2.predict(x_test_nom)
# Out:
# 2023-02-28 12:42:43.641995: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_1/bias/Assign' id:125 op device:{requested: '', assigned: ''} def:{{{node dense_1/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_1/bias, dense_1/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:43.784454: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_1/Softmax' id:131 op device:{requested: '', assigned: ''} def:{{{node dense_1/Softmax}} = Softmax[T=DT_FLOAT, _has_manual_control_dependencies=true](dense_1/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:43.805702: W tensorflow/c/c_api.cc:291] Operation '{name:'total/Assign' id:169 op device:{requested: '', assigned: ''} def:{{{node total/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](total, total/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(fit2.history['loss'], color='b', label="Training Loss")
ax[0].plot(fit2.history['val_loss'], color='r', label="Validation Training Loss")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(fit2.history['acc'], color='b', label="Training Accuracy")
ax[1].plot(fit2.history['val_acc'], color='r', label="Validation Training Accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
score2 = best_model2.evaluate(x_test_nom, y_test_onehot, verbose = 0) 

print('Test loss:', score2[0]) 
print('Test accuracy:', score2[1])
# Out:
# 2023-02-28 12:42:45.297181: W tensorflow/c/c_api.cc:291] Operation '{name:'loss/AddN_1' id:266 op device:{requested: '', assigned: ''} def:{{{node loss/AddN_1}} = AddN[N=2, T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul, loss/AddN)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test loss: 0.9607593044281005
# Test accuracy: 0.7279

# %%
sample_no = 0

best_model2_no_softmax = innvestigate.model_wo_softmax(best_model2)

analyzer_gradient2 = innvestigate.create_analyzer("gradient", best_model2_no_softmax)
a2g = analyzer_gradient2.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a2g = a2g.sum(axis=np.argmax(np.asarray(a2g.shape) == 3))
a2g /= np.max(np.abs(a2g))

analyzer_gradient2 = innvestigate.create_analyzer("input_t_gradient", best_model2_no_softmax)
a2itg = analyzer_gradient2.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a2itg = a2itg.sum(axis=np.argmax(np.asarray(a2itg.shape) == 3))
a2itg /= np.max(np.abs(a2itg))

analyzer_gradient2 = innvestigate.create_analyzer("deep_taylor", best_model2_no_softmax)
a2dt = analyzer_gradient2.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a2dt = a2dt.sum(axis=np.argmax(np.asarray(a2dt.shape) == 3))
a2dt /= np.max(np.abs(a2dt))

analyzer_gradient2 = innvestigate.create_analyzer("integrated_gradients", best_model2_no_softmax)
a2ig = analyzer_gradient2.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a2ig = a2ig.sum(axis=np.argmax(np.asarray(a2ig.shape) == 3))
a2ig /= np.max(np.abs(a2ig))

analyzer_gradient2 = innvestigate.create_analyzer("lrp.z", best_model2_no_softmax)
a2lrpz = analyzer_gradient2.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a2lrpz = a2lrpz.sum(axis=np.argmax(np.asarray(a2lrpz.shape) == 3))
a2lrpz /= np.max(np.abs(a2lrpz))

analyzer_gradient2 = innvestigate.create_analyzer("lrp.epsilon", best_model2_no_softmax)
a2lrpe = analyzer_gradient2.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a2lrpe = a2lrpe.sum(axis=np.argmax(np.asarray(a2lrpe.shape) == 3))
a2lrpe /= np.max(np.abs(a2lrpe))

analyzer_gradient2 = innvestigate.create_analyzer("lrp.alpha_1_beta_0", best_model2_no_softmax)
a2lrpa1b0 = analyzer_gradient2.analyze(x_train_nom[sample_no][np.newaxis,:])

# Aggregate along color channels and normalize to [-1, 1]
a2lrpa1b0 = a2lrpa1b0.sum(axis=np.argmax(np.asarray(a2lrpa1b0.shape) == 3))
a2lrpa1b0 /= np.max(np.abs(a2lrpa1b0))
# Out:
# 2023-02-28 12:42:46.697320: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:46.744081: W tensorflow/c/c_api.cc:291] Operation '{name:'bias/Assign' id:295 op device:{requested: '', assigned: ''} def:{{{node bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](bias, bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:46.800387: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:46.841043: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:46.881453: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:46.920677: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:46.961045: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.000945: W tensorflow/c/c_api.cc:291] Operation '{name:'dense/MatMul/ReadVariableOp' id:94 op device:{requested: '', assigned: ''} def:{{{node dense/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.040913: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.081263: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_2/MatMul/ReadVariableOp' id:297 op device:{requested: '', assigned: ''} def:{{{node dense_2/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.121309: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/range' id:315 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/range/start, gradients/MaxNeuronSelection/Max_grad/Size, gradients/MaxNeuronSelection/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.161437: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/mod' id:311 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true](gradients/MaxNeuronSelection/Max_grad/add, gradients/MaxNeuronSelection/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.200954: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients/MaxNeuronSelection/Max_grad/ones' id:317 op device:{requested: '', assigned: ''} def:{{{node gradients/MaxNeuronSelection/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients/MaxNeuronSelection/Max_grad/Shape_1, gradients/MaxNeuronSelection/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.245313: W tensorflow/c/c_api.cc:291] Operation '{name:'MaxNeuronSelection/Max/reduction_indices' id:302 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.286733: W tensorflow/c/c_api.cc:291] Operation '{name:'ones_like/Const' id:305 op device:{requested: '', assigned: ''} def:{{{node ones_like/Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.332448: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.385248: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.438383: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.494123: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_10/conv2d/Conv2D_grad/Conv2DBackpropInput' id:384 op device:{requested: '', assigned: ''} def:{{{node gradients_10/conv2d/Conv2D_grad/Conv2DBackpropInput}} = Conv2DBackpropInput[T=DT_FLOAT, _class=["loc:@conv2d/Conv2D"], _has_manual_control_dependencies=true, data_format="NHWC", dilations=[1, 1, 1, 1], explicit_paddings=[], padding="VALID", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true](gradients_10/conv2d/Conv2D_grad/ShapeN, conv2d/Conv2D/ReadVariableOp, gradients_10/conv2d/Relu_grad/ReluGrad)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:47.964885: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.021310: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.073336: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.120471: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.164676: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.208786: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.251589: W tensorflow/c/c_api.cc:291] Operation '{name:'dense/MatMul/ReadVariableOp' id:94 op device:{requested: '', assigned: ''} def:{{{node dense/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.293291: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.335695: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_2/MatMul/ReadVariableOp' id:297 op device:{requested: '', assigned: ''} def:{{{node dense_2/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.378098: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_11/MaxNeuronSelection_1/Max_grad/range' id:421 op device:{requested: '', assigned: ''} def:{{{node gradients_11/MaxNeuronSelection_1/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true](gradients_11/MaxNeuronSelection_1/Max_grad/range/start, gradients_11/MaxNeuronSelection_1/Max_grad/Size, gradients_11/MaxNeuronSelection_1/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.419738: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_11/MaxNeuronSelection_1/Max_grad/mod' id:417 op device:{requested: '', assigned: ''} def:{{{node gradients_11/MaxNeuronSelection_1/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true](gradients_11/MaxNeuronSelection_1/Max_grad/add, gradients_11/MaxNeuronSelection_1/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.461420: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_11/MaxNeuronSelection_1/Max_grad/ones' id:423 op device:{requested: '', assigned: ''} def:{{{node gradients_11/MaxNeuronSelection_1/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_1/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_11/MaxNeuronSelection_1/Max_grad/Shape_1, gradients_11/MaxNeuronSelection_1/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.506681: W tensorflow/c/c_api.cc:291] Operation '{name:'MaxNeuronSelection_1/Max/reduction_indices' id:408 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_1/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:48.550625: W tensorflow/c/c_api.cc:291] Operation '{name:'ones_like_1/Const' id:411 op device:{requested: '', assigned: ''} def:{{{node ones_like_1/Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.268441: W tensorflow/c/c_api.cc:291] Operation '{name:'kernel_3/Assign' id:576 op device:{requested: '', assigned: ''} def:{{{node kernel_3/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_3, kernel_3/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.355331: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_22/MaxNeuronSelection_2/Max_grad/range' id:680 op device:{requested: '', assigned: ''} def:{{{node gradients_22/MaxNeuronSelection_2/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true](gradients_22/MaxNeuronSelection_2/Max_grad/range/start, gradients_22/MaxNeuronSelection_2/Max_grad/Size, gradients_22/MaxNeuronSelection_2/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.402769: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_22/MaxNeuronSelection_2/Max_grad/mod' id:676 op device:{requested: '', assigned: ''} def:{{{node gradients_22/MaxNeuronSelection_2/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true](gradients_22/MaxNeuronSelection_2/Max_grad/add, gradients_22/MaxNeuronSelection_2/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.449797: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_22/MaxNeuronSelection_2/Max_grad/ones' id:682 op device:{requested: '', assigned: ''} def:{{{node gradients_22/MaxNeuronSelection_2/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_2/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_22/MaxNeuronSelection_2/Max_grad/Shape_1, gradients_22/MaxNeuronSelection_2/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.500038: W tensorflow/c/c_api.cc:291] Operation '{name:'MaxNeuronSelection_2/Max/reduction_indices' id:510 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_2/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.551961: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_8/x' id:709 op device:{requested: '', assigned: ''} def:{{{node mul_8/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.598460: W tensorflow/c/c_api.cc:291] Operation '{name:'Const' id:706 op device:{requested: '', assigned: ''} def:{{{node Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.649826: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_7' id:643 op device:{requested: '', assigned: ''} def:{{{node mul_7}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_25, Cast_7)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.778105: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_4' id:597 op device:{requested: '', assigned: ''} def:{{{node mul_4}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_19, Cast_4)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.836005: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.893566: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_9/x' id:763 op device:{requested: '', assigned: ''} def:{{{node mul_9/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:49.944205: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_1' id:760 op device:{requested: '', assigned: ''} def:{{{node Const_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.000547: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_5' id:603 op device:{requested: '', assigned: ''} def:{{{node mul_5}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_21, Cast_5)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.149218: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_2' id:557 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_15, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.210707: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_2' id:557 op device:{requested: '', assigned: ''} def:{{{node mul_2}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_15, Cast_2)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.270402: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.335440: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_10/x' id:810 op device:{requested: '', assigned: ''} def:{{{node mul_10/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.391050: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_2' id:807 op device:{requested: '', assigned: ''} def:{{{node Const_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.452336: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_3' id:563 op device:{requested: '', assigned: ''} def:{{{node mul_3}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_17, Cast_3)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.511243: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_3' id:563 op device:{requested: '', assigned: ''} def:{{{node mul_3}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_17, Cast_3)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.661826: W tensorflow/c/c_api.cc:291] Operation '{name:'mul' id:517 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_11, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.728108: W tensorflow/c/c_api.cc:291] Operation '{name:'mul' id:517 op device:{requested: '', assigned: ''} def:{{{node mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_11, Cast)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.793283: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.861864: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_11/x' id:858 op device:{requested: '', assigned: ''} def:{{{node mul_11/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.923040: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_3' id:855 op device:{requested: '', assigned: ''} def:{{{node Const_3}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:50.990682: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_1' id:523 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_13, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:51.056742: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_1' id:523 op device:{requested: '', assigned: ''} def:{{{node mul_1}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_13, Cast_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:51.744366: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:51.850781: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d/Conv2D/ReadVariableOp' id:24 op device:{requested: '', assigned: ''} def:{{{node conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:51.952909: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:52.039288: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:52.118831: W tensorflow/c/c_api.cc:291] Operation '{name:'conv2d_1/Conv2D/ReadVariableOp' id:58 op device:{requested: '', assigned: ''} def:{{{node conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:52.195437: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:52.270056: W tensorflow/c/c_api.cc:291] Operation '{name:'dense/MatMul/ReadVariableOp' id:94 op device:{requested: '', assigned: ''} def:{{{node dense/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:52.343696: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:52.417161: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_2/MatMul/ReadVariableOp' id:297 op device:{requested: '', assigned: ''} def:{{{node dense_2/MatMul/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](dense_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:52.491473: W tensorflow/c/c_api.cc:291] Operation '{name:'ones_like_2/Const' id:884 op device:{requested: '', assigned: ''} def:{{{node ones_like_2/Const}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:52.801267: W tensorflow/c/c_api.cc:291] Operation '{name:'dense_2/BiasAdd' id:300 op device:{requested: '', assigned: ''} def:{{{node dense_2/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_2/MatMul, dense_2/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:52.936106: W tensorflow/c/c_api.cc:291] Operation '{name:'Variable/Assign' id:960 op device:{requested: '', assigned: ''} def:{{{node Variable/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](Variable, Variable/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:53.133617: W tensorflow/c/c_api.cc:291] Operation '{name:'multiply_9/mul' id:1113 op device:{requested: '', assigned: ''} def:{{{node multiply_9/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](reduce_mean/Mean, subtract/sub)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:53.635741: W tensorflow/c/c_api.cc:291] Operation '{name:'kernel_10/Assign' id:1153 op device:{requested: '', assigned: ''} def:{{{node kernel_10/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](kernel_10, kernel_10/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:53.785129: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_49/MaxNeuronSelection_3/Max_grad/range' id:1206 op device:{requested: '', assigned: ''} def:{{{node gradients_49/MaxNeuronSelection_3/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_3/Max"], _has_manual_control_dependencies=true](gradients_49/MaxNeuronSelection_3/Max_grad/range/start, gradients_49/MaxNeuronSelection_3/Max_grad/Size, gradients_49/MaxNeuronSelection_3/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:53.888657: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_49/MaxNeuronSelection_3/Max_grad/mod' id:1202 op device:{requested: '', assigned: ''} def:{{{node gradients_49/MaxNeuronSelection_3/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_3/Max"], _has_manual_control_dependencies=true](gradients_49/MaxNeuronSelection_3/Max_grad/add, gradients_49/MaxNeuronSelection_3/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:53.993823: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_49/MaxNeuronSelection_3/Max_grad/ones' id:1208 op device:{requested: '', assigned: ''} def:{{{node gradients_49/MaxNeuronSelection_3/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_3/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_49/MaxNeuronSelection_3/Max_grad/Shape_1, gradients_49/MaxNeuronSelection_3/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:54.102127: W tensorflow/c/c_api.cc:291] Operation '{name:'MaxNeuronSelection_3/Max/reduction_indices' id:1120 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_3/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:54.208907: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_12/x' id:1226 op device:{requested: '', assigned: ''} def:{{{node mul_12/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:54.316645: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_4' id:1223 op device:{requested: '', assigned: ''} def:{{{node Const_4}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:54.611921: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:54.729794: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_13/x' id:1268 op device:{requested: '', assigned: ''} def:{{{node mul_13/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:54.839958: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_5' id:1265 op device:{requested: '', assigned: ''} def:{{{node Const_5}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:55.163029: W tensorflow/c/c_api.cc:291] Operation '{name:'reversed_kernel_conv2d_1/Conv2D/ReadVariableOp' id:1296 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:55.279573: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:55.405729: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_14/x' id:1303 op device:{requested: '', assigned: ''} def:{{{node mul_14/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:55.520868: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_6' id:1300 op device:{requested: '', assigned: ''} def:{{{node Const_6}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:55.854991: W tensorflow/c/c_api.cc:291] Operation '{name:'reversed_kernel_conv2d/Conv2D/ReadVariableOp' id:1330 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:55.977955: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:56.107864: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_15/x' id:1337 op device:{requested: '', assigned: ''} def:{{{node mul_15/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:56.228639: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_7' id:1334 op device:{requested: '', assigned: ''} def:{{{node Const_7}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:56.801451: W tensorflow/c/c_api.cc:291] Operation '{name:'bias_5/Assign' id:1373 op device:{requested: '', assigned: ''} def:{{{node bias_5/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](bias_5, bias_5/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# ...
# 2023-02-28 12:42:58.503794: W tensorflow/c/c_api.cc:291] Operation '{name:'reversed_kernel_conv2d_1_1/Conv2D/ReadVariableOp' id:1534 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_1_1/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d_1/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:58.727920: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:59.288996: W tensorflow/c/c_api.cc:291] Operation '{name:'reversed_kernel_conv2d_2/Conv2D/ReadVariableOp' id:1570 op device:{requested: '', assigned: ''} def:{{{node reversed_kernel_conv2d_2/Conv2D/ReadVariableOp}} = ReadVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT](conv2d/kernel)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:42:59.514053: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:00.475371: W tensorflow/c/c_api.cc:291] Operation '{name:'bias_9/Assign' id:1639 op device:{requested: '', assigned: ''} def:{{{node bias_9/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](bias_9, bias_9/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:00.711410: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_71/MaxNeuronSelection_5/Max_grad/range' id:1854 op device:{requested: '', assigned: ''} def:{{{node gradients_71/MaxNeuronSelection_5/Max_grad/range}} = Range[Tidx=DT_INT32, _class=["loc:@MaxNeuronSelection_5/Max"], _has_manual_control_dependencies=true](gradients_71/MaxNeuronSelection_5/Max_grad/range/start, gradients_71/MaxNeuronSelection_5/Max_grad/Size, gradients_71/MaxNeuronSelection_5/Max_grad/range/delta)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:00.869010: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_71/MaxNeuronSelection_5/Max_grad/mod' id:1850 op device:{requested: '', assigned: ''} def:{{{node gradients_71/MaxNeuronSelection_5/Max_grad/mod}} = FloorMod[T=DT_INT32, _class=["loc:@MaxNeuronSelection_5/Max"], _has_manual_control_dependencies=true](gradients_71/MaxNeuronSelection_5/Max_grad/add, gradients_71/MaxNeuronSelection_5/Max_grad/Size)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:01.030442: W tensorflow/c/c_api.cc:291] Operation '{name:'gradients_71/MaxNeuronSelection_5/Max_grad/ones' id:1856 op device:{requested: '', assigned: ''} def:{{{node gradients_71/MaxNeuronSelection_5/Max_grad/ones}} = Fill[T=DT_INT32, _class=["loc:@MaxNeuronSelection_5/Max"], _has_manual_control_dependencies=true, index_type=DT_INT32](gradients_71/MaxNeuronSelection_5/Max_grad/Shape_1, gradients_71/MaxNeuronSelection_5/Max_grad/ones/Const)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:01.192772: W tensorflow/c/c_api.cc:291] Operation '{name:'MaxNeuronSelection_5/Max/reduction_indices' id:1596 op device:{requested: '', assigned: ''} def:{{{node MaxNeuronSelection_5/Max/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: -1>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:01.361398: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_32/x' id:1883 op device:{requested: '', assigned: ''} def:{{{node mul_32/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:01.525575: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_8' id:1880 op device:{requested: '', assigned: ''} def:{{{node Const_8}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:01.689679: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_30' id:1801 op device:{requested: '', assigned: ''} def:{{{node mul_30}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_56, Cast_30)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:01.954774: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_24' id:1727 op device:{requested: '', assigned: ''} def:{{{node mul_24}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_44, Cast_24)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:02.130633: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:02.310239: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_33/x' id:1949 op device:{requested: '', assigned: ''} def:{{{node mul_33/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:02.479334: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_9' id:1946 op device:{requested: '', assigned: ''} def:{{{node Const_9}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:02.657741: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_26' id:1739 op device:{requested: '', assigned: ''} def:{{{node mul_26}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_48, Cast_26)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:02.953485: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_20' id:1665 op device:{requested: '', assigned: ''} def:{{{node mul_20}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_36, Cast_20)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:03.130529: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_20' id:1665 op device:{requested: '', assigned: ''} def:{{{node mul_20}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_36, Cast_20)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:03.313135: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:03.499314: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_34/x' id:2000 op device:{requested: '', assigned: ''} def:{{{node mul_34/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:03.672267: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_10' id:1997 op device:{requested: '', assigned: ''} def:{{{node Const_10}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:03.855106: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_22' id:1677 op device:{requested: '', assigned: ''} def:{{{node mul_22}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_40, Cast_22)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:04.035783: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_22' id:1677 op device:{requested: '', assigned: ''} def:{{{node mul_22}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_40, Cast_22)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:04.380505: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_16' id:1603 op device:{requested: '', assigned: ''} def:{{{node mul_16}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_28, Cast_16)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:04.606556: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_16' id:1603 op device:{requested: '', assigned: ''} def:{{{node mul_16}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_28, Cast_16)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:04.831288: W tensorflow/c/c_api.cc:291] Operation '{name:'keras_learning_phase' id:3 op device:{requested: '', assigned: ''} def:{{{node keras_learning_phase}} = PlaceholderWithDefault[_has_manual_control_dependencies=true, dtype=DT_BOOL, shape=[]](keras_learning_phase/input)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:05.055063: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_35/x' id:2052 op device:{requested: '', assigned: ''} def:{{{node mul_35/x}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 1e-07>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:05.231785: W tensorflow/c/c_api.cc:291] Operation '{name:'Const_11' id:2049 op device:{requested: '', assigned: ''} def:{{{node Const_11}} = Const[_has_manual_control_dependencies=true, dtype=DT_FLOAT, value=Tensor<type: float shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:05.413187: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_18' id:1615 op device:{requested: '', assigned: ''} def:{{{node mul_18}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_32, Cast_18)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-02-28 12:43:05.591729: W tensorflow/c/c_api.cc:291] Operation '{name:'mul_18' id:1615 op device:{requested: '', assigned: ''} def:{{{node mul_18}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](ReadVariableOp_32, Cast_18)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
# Plot
plt.rcParams['figure.figsize'] = [10, 10]
fig, ax = plt.subplots(1,8)
fig.subplots_adjust(hspace=0, wspace=0)

ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)
ax[0].spines['bottom'].set_visible(False)
ax[0].spines['left'].set_visible(False)      
ax[0].imshow(x_train_nom[sample_no])
ax[0].set_xticklabels([])
ax[0].set_yticklabels([])
ax[0].tick_params(left=False)
ax[0].tick_params(bottom=False)
#ax[0].axis('off')
ax[0].set_xlabel('sample', fontsize=7)

ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)
ax[1].spines['bottom'].set_visible(False)
ax[1].spines['left'].set_visible(False) 
# ax[1].imshow(a2[0], cmap="seismic")
ax[1].imshow(a2g[0], cmap="seismic", clim=(-1, 1))
# ax[1].imshow(x_train_nom[sample_no])
ax[1].set_xticklabels([])
ax[1].set_yticklabels([])
ax[1].tick_params(left=False)
ax[1].tick_params(bottom=False)
#ax[1].axis('off')
ax[1].set_xlabel('gradient', fontsize=7)

ax[2].spines['top'].set_visible(False)
ax[2].spines['right'].set_visible(False)
ax[2].spines['bottom'].set_visible(False)
ax[2].spines['left'].set_visible(False) 
ax[2].imshow(a2itg[0], cmap="seismic", clim=(-1, 1))
ax[2].set_xticklabels([])
ax[2].set_yticklabels([])
ax[2].tick_params(left=False)
ax[2].tick_params(bottom=False)
#ax[2].axis('off')
ax[2].set_xlabel('input*gradient', fontsize=7)

ax[3].spines['top'].set_visible(False)
ax[3].spines['right'].set_visible(False)
ax[3].spines['bottom'].set_visible(False)
ax[3].spines['left'].set_visible(False) 
ax[3].imshow(a2dt[0], cmap="seismic", clim=(-1, 1))
ax[3].set_xticklabels([])
ax[3].set_yticklabels([])
ax[3].tick_params(left=False)
ax[3].tick_params(bottom=False)
#ax[3].axis('off')
ax[3].set_xlabel('Deep Taylor', fontsize=7)

ax[4].spines['top'].set_visible(False)
ax[4].spines['right'].set_visible(False)
ax[4].spines['bottom'].set_visible(False)
ax[4].spines['left'].set_visible(False) 
ax[4].imshow(a2ig[0], cmap="seismic", clim=(-1, 1))
ax[4].set_xticklabels([])
ax[4].set_yticklabels([])
ax[4].tick_params(left=False)
ax[4].tick_params(bottom=False)
#ax[4].axis('off')
ax[4].set_xlabel('integrated gradients', fontsize=7)

ax[5].spines['top'].set_visible(False)
ax[5].spines['right'].set_visible(False)
ax[5].spines['bottom'].set_visible(False)
ax[5].spines['left'].set_visible(False) 
ax[5].imshow(a2lrpz[0], cmap="seismic", clim=(-1, 1))
ax[5].set_xticklabels([])
ax[5].set_yticklabels([])
ax[5].tick_params(left=False)
ax[5].tick_params(bottom=False)
#ax[5].axis('off')
ax[5].set_xlabel('LRP-z', fontsize=7)

ax[6].spines['top'].set_visible(False)
ax[6].spines['right'].set_visible(False)
ax[6].spines['bottom'].set_visible(False)
ax[6].spines['left'].set_visible(False)
ax[6].imshow(a2lrpe[0], cmap="seismic", clim=(-1, 1))
ax[6].set_xticklabels([])
ax[6].set_yticklabels([])
ax[6].tick_params(left=False)
ax[6].tick_params(bottom=False)
#ax[6].axis('off')
ax[6].set_xlabel('LRP-epsilon', fontsize=7)

ax[7].spines['top'].set_visible(False)
ax[7].spines['right'].set_visible(False)
ax[7].spines['bottom'].set_visible(False)
ax[7].spines['left'].set_visible(False)
ax[7].imshow(a2lrpa1b0[0], cmap="seismic", clim=(-1, 1))
ax[7].set_xticklabels([])
ax[7].set_yticklabels([])
ax[7].tick_params(left=False)
ax[7].tick_params(bottom=False)
#ax[7].axis('off')
ax[7].set_xlabel('LRP-alpha1-beta0', fontsize=7)
# Out:
# Text(0.5, 0, 'LRP-alpha1-beta0')
